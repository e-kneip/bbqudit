# %%
from bbq.decoder import bp_osd
import numpy as np
from ldpc import BpDecoder, bposd_decoder
from bbq.polynomial import Polynomial, Monomial
from bbq.bbq_code import BivariateBicycle
from bbq.field import Field
import matplotlib.pyplot as plt
import json
import datetime
import galois
from ldpc import bposd_decoder

# %%
my_bp_method = "ms"
my_max_iter = 300
my_osd_method = "osd_cs"
my_osd_order = 0
my_ms_scaling_factor = 0

# %%
def simulate_ldpc(field, h, l, max_iter, num_failures, physical_error, my_bp_method = "ms", my_max_iter = 300, my_osd_method = "osd_cs", my_osd_order = 0, my_ms_scaling_factor = 0):

    results = []

    for p in physical_error:

        failures = 0
        num_trials = 0

        n_qudits = h.shape[1]

        bpd = bposd_decoder(
            h,
            error_rate = float(p),
            max_iter = my_max_iter,
            bp_method = my_bp_method,
            ms_scaling_factor = my_ms_scaling_factor,
            osd_method = my_osd_method,
            osd_order = my_osd_order
            )

        while failures < num_failures:
            # Generate syndrome
            error = np.zeros(n_qudits, dtype=int)
            error_mask = np.random.rand(n_qudits) < p
            for i in np.where(error_mask)[0]:
                error[i] = np.random.randint(1, field.p)
            syndrome = (h @ error) % field.p

            # Decode
            # guessed_error, decoder_success, bp_success, posterior = belief_propagation(field, h, syndrome, x_prior, max_iter, debug=True)
            bpd.decode(syndrome)
            guessed_error = bpd.osdw_decoding
            error_difference = (error - guessed_error) % field.p
            logical_effect = (np.array(l) @ error_difference) % field.p

            # Check success
            # if np.any(logical_effect != 0) or not decoder_success:
            if np.any(logical_effect != 0):
                failures += 1
                print(f'Found {failures} / {num_failures}, with num_trials : {num_trials}')
            elif num_trials % 100 == 0:
                print(f'UPDATE: Found {failures} / {num_failures}, with num_trials : {num_trials}')

            num_trials += 1

        results.append(num_trials)

        print(f'Finished p={p} with num_trials={num_trials}')
        print('------------------------------------------------------------------')
    return results

# %%
results = np.flip(simulate_ldpc(field, h72, l72, max_iter, 20, physical_error))
# Out:
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 12
# Found 14 / 20, with num_trials : 13
# Found 15 / 20, with num_trials : 14
# Found 16 / 20, with num_trials : 15
# Found 17 / 20, with num_trials : 16
# Found 18 / 20, with num_trials : 17
# Found 19 / 20, with num_trials : 18
# Found 20 / 20, with num_trials : 19
# Finished p=0.19952623149688797 with num_trials=20
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 3
# Found 4 / 20, with num_trials : 5
# Found 5 / 20, with num_trials : 6
# Found 6 / 20, with num_trials : 7
# Found 7 / 20, with num_trials : 8
# Found 8 / 20, with num_trials : 9
# Found 9 / 20, with num_trials : 10
# Found 10 / 20, with num_trials : 11
# Found 11 / 20, with num_trials : 12
# Found 12 / 20, with num_trials : 13
# Found 13 / 20, with num_trials : 14
# Found 14 / 20, with num_trials : 15
# Found 15 / 20, with num_trials : 16
# Found 16 / 20, with num_trials : 17
# Found 17 / 20, with num_trials : 18
# Found 18 / 20, with num_trials : 19
# Found 19 / 20, with num_trials : 20
# Found 20 / 20, with num_trials : 21
# Finished p=0.15448591479026755 with num_trials=22
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 5
# Found 6 / 20, with num_trials : 6
# Found 7 / 20, with num_trials : 7
# Found 8 / 20, with num_trials : 8
# Found 9 / 20, with num_trials : 9
# Found 10 / 20, with num_trials : 10
# Found 11 / 20, with num_trials : 12
# Found 12 / 20, with num_trials : 13
# Found 13 / 20, with num_trials : 14
# Found 14 / 20, with num_trials : 16
# Found 15 / 20, with num_trials : 17
# Found 16 / 20, with num_trials : 19
# Found 17 / 20, with num_trials : 20
# Found 18 / 20, with num_trials : 21
# Found 19 / 20, with num_trials : 22
# Found 20 / 20, with num_trials : 23
# Finished p=0.11961283330787534 with num_trials=24
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 4
# Found 3 / 20, with num_trials : 5
# Found 4 / 20, with num_trials : 6
# Found 5 / 20, with num_trials : 8
# Found 6 / 20, with num_trials : 9
# Found 7 / 20, with num_trials : 12
# Found 8 / 20, with num_trials : 13
# Found 9 / 20, with num_trials : 16
# Found 10 / 20, with num_trials : 23
# Found 11 / 20, with num_trials : 26
# Found 12 / 20, with num_trials : 27
# Found 13 / 20, with num_trials : 28
# Found 14 / 20, with num_trials : 29
# Found 15 / 20, with num_trials : 30
# Found 16 / 20, with num_trials : 32
# Found 17 / 20, with num_trials : 33
# Found 18 / 20, with num_trials : 34
# Found 19 / 20, with num_trials : 37
# Found 20 / 20, with num_trials : 40
# Finished p=0.09261187281287937 with num_trials=41
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 1
# Found 2 / 20, with num_trials : 4
# Found 3 / 20, with num_trials : 6
# Found 4 / 20, with num_trials : 8
# Found 5 / 20, with num_trials : 9
# Found 6 / 20, with num_trials : 11
# Found 7 / 20, with num_trials : 13
# Found 8 / 20, with num_trials : 14
# Found 9 / 20, with num_trials : 17
# Found 10 / 20, with num_trials : 18
# Found 11 / 20, with num_trials : 19
# Found 12 / 20, with num_trials : 20
# Found 13 / 20, with num_trials : 26
# Found 14 / 20, with num_trials : 27
# Found 15 / 20, with num_trials : 42
# Found 16 / 20, with num_trials : 46
# Found 17 / 20, with num_trials : 48
# Found 18 / 20, with num_trials : 49
# Found 19 / 20, with num_trials : 51
# Found 20 / 20, with num_trials : 53
# Finished p=0.07170600970409613 with num_trials=54
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 5
# Found 2 / 20, with num_trials : 10
# Found 3 / 20, with num_trials : 14
# Found 4 / 20, with num_trials : 23
# Found 5 / 20, with num_trials : 29
# Found 6 / 20, with num_trials : 43
# Found 7 / 20, with num_trials : 48
# Found 8 / 20, with num_trials : 52
# Found 9 / 20, with num_trials : 54
# Found 10 / 20, with num_trials : 60
# Found 11 / 20, with num_trials : 63
# Found 12 / 20, with num_trials : 67
# Found 13 / 20, with num_trials : 80
# Found 14 / 20, with num_trials : 89
# Found 15 / 20, with num_trials : 91
# UPDATE: Found 15 / 20, with num_trials : 100
# Found 16 / 20, with num_trials : 105
# Found 17 / 20, with num_trials : 110
# Found 18 / 20, with num_trials : 111
# Found 19 / 20, with num_trials : 113
# Found 20 / 20, with num_trials : 115
# Finished p=0.05551935914386209 with num_trials=116
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 3
# Found 3 / 20, with num_trials : 9
# Found 4 / 20, with num_trials : 13
# Found 5 / 20, with num_trials : 17
# Found 6 / 20, with num_trials : 35
# Found 7 / 20, with num_trials : 48
# Found 8 / 20, with num_trials : 51
# Found 9 / 20, with num_trials : 52
# Found 10 / 20, with num_trials : 68
# Found 11 / 20, with num_trials : 69
# Found 12 / 20, with num_trials : 71
# Found 13 / 20, with num_trials : 77
# Found 14 / 20, with num_trials : 81
# Found 15 / 20, with num_trials : 86
# Found 16 / 20, with num_trials : 93
# UPDATE: Found 16 / 20, with num_trials : 100
# Found 17 / 20, with num_trials : 102
# Found 18 / 20, with num_trials : 114
# Found 19 / 20, with num_trials : 123
# Found 20 / 20, with num_trials : 128
# Finished p=0.042986623470822764 with num_trials=129
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 22
# Found 2 / 20, with num_trials : 36
# Found 3 / 20, with num_trials : 83
# Found 4 / 20, with num_trials : 89
# Found 5 / 20, with num_trials : 90
# Found 6 / 20, with num_trials : 100
# Found 7 / 20, with num_trials : 101
# Found 8 / 20, with num_trials : 109
# Found 9 / 20, with num_trials : 120
# Found 10 / 20, with num_trials : 122
# Found 11 / 20, with num_trials : 124
# Found 12 / 20, with num_trials : 125
# Found 13 / 20, with num_trials : 132
# Found 14 / 20, with num_trials : 133
# Found 15 / 20, with num_trials : 138
# Found 16 / 20, with num_trials : 163
# Found 17 / 20, with num_trials : 189
# Found 18 / 20, with num_trials : 190
# UPDATE: Found 18 / 20, with num_trials : 200
# Found 19 / 20, with num_trials : 251
# Found 20 / 20, with num_trials : 253
# Finished p=0.033282981394546204 with num_trials=254
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 13
# Found 2 / 20, with num_trials : 14
# Found 3 / 20, with num_trials : 17
# Found 4 / 20, with num_trials : 26
# Found 5 / 20, with num_trials : 29
# Found 6 / 20, with num_trials : 39
# Found 7 / 20, with num_trials : 68
# Found 8 / 20, with num_trials : 84
# Found 9 / 20, with num_trials : 93
# Found 10 / 20, with num_trials : 98
# UPDATE: Found 10 / 20, with num_trials : 100
# Found 11 / 20, with num_trials : 121
# Found 12 / 20, with num_trials : 125
# Found 13 / 20, with num_trials : 130
# Found 14 / 20, with num_trials : 134
# Found 15 / 20, with num_trials : 135
# Found 16 / 20, with num_trials : 136
# Found 17 / 20, with num_trials : 150
# Found 18 / 20, with num_trials : 154
# Found 19 / 20, with num_trials : 158
# Found 20 / 20, with num_trials : 160
# Finished p=0.025769803745148787 with num_trials=161
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 2
# Found 2 / 20, with num_trials : 4
# Found 3 / 20, with num_trials : 18
# Found 4 / 20, with num_trials : 21
# Found 5 / 20, with num_trials : 26
# Found 6 / 20, with num_trials : 33
# Found 7 / 20, with num_trials : 35
# Found 8 / 20, with num_trials : 36
# Found 9 / 20, with num_trials : 42
# Found 10 / 20, with num_trials : 63
# Found 11 / 20, with num_trials : 69
# Found 12 / 20, with num_trials : 70
# Found 13 / 20, with num_trials : 75
# Found 14 / 20, with num_trials : 81
# Found 15 / 20, with num_trials : 82
# Found 16 / 20, with num_trials : 85
# Found 17 / 20, with num_trials : 91
# Found 18 / 20, with num_trials : 93
# Found 19 / 20, with num_trials : 100
# Found 20 / 20, with num_trials : 102
# Finished p=0.0199526231496888 with num_trials=103
# ------------------------------------------------------------------

# %%
results
# Out:
# array([103, 161, 254, 129, 116,  54,  41,  24,  22,  20])

# %%
results = np.flip(simulate_ldpc(field, h108, l108, max_iter, 20, physical_error))
# Out:
# c:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\bbq_venv\Lib\site-packages\ldpc\_legacy_ldpc_v1\_legacy_bposd_decoder.py:45: UserWarning: This is the old syntax for the `bposd_decoder` from `ldpc v1`. Use the `BpOsdDecoder` class from `ldpc v2` for additional features.
#   warnings.warn(
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 12
# Found 14 / 20, with num_trials : 13
# Found 15 / 20, with num_trials : 14
# Found 16 / 20, with num_trials : 15
# Found 17 / 20, with num_trials : 16
# Found 18 / 20, with num_trials : 18
# Found 19 / 20, with num_trials : 19
# Found 20 / 20, with num_trials : 20
# Finished p=0.19952623149688797 with num_trials=21
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 12
# Found 14 / 20, with num_trials : 13
# Found 15 / 20, with num_trials : 14
# Found 16 / 20, with num_trials : 15
# Found 17 / 20, with num_trials : 16
# Found 18 / 20, with num_trials : 17
# Found 19 / 20, with num_trials : 18
# Found 20 / 20, with num_trials : 19
# Finished p=0.15448591479026755 with num_trials=20
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 3
# Found 4 / 20, with num_trials : 4
# Found 5 / 20, with num_trials : 5
# Found 6 / 20, with num_trials : 6
# Found 7 / 20, with num_trials : 7
# Found 8 / 20, with num_trials : 8
# Found 9 / 20, with num_trials : 9
# Found 10 / 20, with num_trials : 10
# Found 11 / 20, with num_trials : 11
# Found 12 / 20, with num_trials : 12
# Found 13 / 20, with num_trials : 13
# Found 14 / 20, with num_trials : 15
# Found 15 / 20, with num_trials : 16
# Found 16 / 20, with num_trials : 17
# Found 17 / 20, with num_trials : 19
# Found 18 / 20, with num_trials : 20
# Found 19 / 20, with num_trials : 21
# Found 20 / 20, with num_trials : 23
# Finished p=0.11961283330787534 with num_trials=24
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 4
# Found 3 / 20, with num_trials : 7
# Found 4 / 20, with num_trials : 8
# Found 5 / 20, with num_trials : 11
# Found 6 / 20, with num_trials : 17
# Found 7 / 20, with num_trials : 18
# Found 8 / 20, with num_trials : 19
# Found 9 / 20, with num_trials : 22
# Found 10 / 20, with num_trials : 23
# Found 11 / 20, with num_trials : 24
# Found 12 / 20, with num_trials : 25
# Found 13 / 20, with num_trials : 27
# Found 14 / 20, with num_trials : 29
# Found 15 / 20, with num_trials : 30
# Found 16 / 20, with num_trials : 31
# Found 17 / 20, with num_trials : 33
# Found 18 / 20, with num_trials : 34
# Found 19 / 20, with num_trials : 35
# Found 20 / 20, with num_trials : 39
# Finished p=0.09261187281287937 with num_trials=40
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 4
# Found 2 / 20, with num_trials : 8
# Found 3 / 20, with num_trials : 10
# Found 4 / 20, with num_trials : 15
# Found 5 / 20, with num_trials : 18
# Found 6 / 20, with num_trials : 20
# Found 7 / 20, with num_trials : 21
# Found 8 / 20, with num_trials : 28
# Found 9 / 20, with num_trials : 29
# Found 10 / 20, with num_trials : 38
# Found 11 / 20, with num_trials : 40
# Found 12 / 20, with num_trials : 41
# Found 13 / 20, with num_trials : 44
# Found 14 / 20, with num_trials : 46
# Found 15 / 20, with num_trials : 55
# Found 16 / 20, with num_trials : 61
# Found 17 / 20, with num_trials : 62
# Found 18 / 20, with num_trials : 68
# Found 19 / 20, with num_trials : 69
# Found 20 / 20, with num_trials : 70
# Finished p=0.07170600970409613 with num_trials=71
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 3
# Found 2 / 20, with num_trials : 6
# Found 3 / 20, with num_trials : 15
# Found 4 / 20, with num_trials : 24
# Found 5 / 20, with num_trials : 39
# Found 6 / 20, with num_trials : 41
# Found 7 / 20, with num_trials : 53
# Found 8 / 20, with num_trials : 54
# Found 9 / 20, with num_trials : 58
# Found 10 / 20, with num_trials : 63
# Found 11 / 20, with num_trials : 75
# Found 12 / 20, with num_trials : 83
# Found 13 / 20, with num_trials : 84
# Found 14 / 20, with num_trials : 90
# UPDATE: Found 14 / 20, with num_trials : 100
# Found 15 / 20, with num_trials : 103
# Found 16 / 20, with num_trials : 123
# Found 17 / 20, with num_trials : 130
# Found 18 / 20, with num_trials : 166
# Found 19 / 20, with num_trials : 168
# Found 20 / 20, with num_trials : 169
# Finished p=0.05551935914386209 with num_trials=170
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 8
# Found 2 / 20, with num_trials : 20
# Found 3 / 20, with num_trials : 57
# UPDATE: Found 3 / 20, with num_trials : 100
# Found 4 / 20, with num_trials : 112
# Found 5 / 20, with num_trials : 156
# Found 6 / 20, with num_trials : 158
# UPDATE: Found 6 / 20, with num_trials : 200
# Found 7 / 20, with num_trials : 204
# Found 8 / 20, with num_trials : 217
# Found 9 / 20, with num_trials : 224
# Found 10 / 20, with num_trials : 245
# Found 11 / 20, with num_trials : 251
# Found 12 / 20, with num_trials : 273
# UPDATE: Found 12 / 20, with num_trials : 300
# Found 13 / 20, with num_trials : 329
# Found 14 / 20, with num_trials : 360
# Found 15 / 20, with num_trials : 365
# Found 16 / 20, with num_trials : 369
# Found 17 / 20, with num_trials : 379
# Found 18 / 20, with num_trials : 381
# Found 19 / 20, with num_trials : 400
# Found 20 / 20, with num_trials : 412
# Finished p=0.042986623470822764 with num_trials=413
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 3
# Found 2 / 20, with num_trials : 26
# Found 3 / 20, with num_trials : 75
# UPDATE: Found 3 / 20, with num_trials : 100
# Found 4 / 20, with num_trials : 164
# Found 5 / 20, with num_trials : 171
# UPDATE: Found 5 / 20, with num_trials : 200
# Found 6 / 20, with num_trials : 217
# Found 7 / 20, with num_trials : 254
# Found 8 / 20, with num_trials : 275
# UPDATE: Found 8 / 20, with num_trials : 300
# UPDATE: Found 8 / 20, with num_trials : 400
# Found 9 / 20, with num_trials : 414
# Found 10 / 20, with num_trials : 415
# Found 11 / 20, with num_trials : 484
# UPDATE: Found 11 / 20, with num_trials : 500
# Found 12 / 20, with num_trials : 530
# Found 13 / 20, with num_trials : 540
# UPDATE: Found 13 / 20, with num_trials : 600
# Found 14 / 20, with num_trials : 647
# Found 15 / 20, with num_trials : 661
# UPDATE: Found 15 / 20, with num_trials : 700
# Found 16 / 20, with num_trials : 705
# Found 17 / 20, with num_trials : 721
# UPDATE: Found 17 / 20, with num_trials : 800
# Found 18 / 20, with num_trials : 837
# Found 19 / 20, with num_trials : 897
# UPDATE: Found 19 / 20, with num_trials : 900
# Found 20 / 20, with num_trials : 942
# Finished p=0.033282981394546204 with num_trials=943
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 14
# Found 2 / 20, with num_trials : 27
# Found 3 / 20, with num_trials : 50
# UPDATE: Found 3 / 20, with num_trials : 100
# Found 4 / 20, with num_trials : 109
# Found 5 / 20, with num_trials : 140
# Found 6 / 20, with num_trials : 146
# Found 7 / 20, with num_trials : 174
# Found 8 / 20, with num_trials : 181
# Found 9 / 20, with num_trials : 189
# Found 10 / 20, with num_trials : 191
# UPDATE: Found 10 / 20, with num_trials : 200
# UPDATE: Found 10 / 20, with num_trials : 300
# Found 11 / 20, with num_trials : 303
# Found 12 / 20, with num_trials : 304
# Found 13 / 20, with num_trials : 315
# Found 14 / 20, with num_trials : 330
# Found 15 / 20, with num_trials : 334
# Found 16 / 20, with num_trials : 352
# Found 17 / 20, with num_trials : 355
# Found 18 / 20, with num_trials : 397
# UPDATE: Found 18 / 20, with num_trials : 400
# Found 19 / 20, with num_trials : 416
# Found 20 / 20, with num_trials : 457
# Finished p=0.025769803745148787 with num_trials=458
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 5
# Found 2 / 20, with num_trials : 15
# Found 3 / 20, with num_trials : 17
# Found 4 / 20, with num_trials : 24
# Found 5 / 20, with num_trials : 35
# Found 6 / 20, with num_trials : 54
# Found 7 / 20, with num_trials : 64
# Found 8 / 20, with num_trials : 65
# Found 9 / 20, with num_trials : 67
# Found 10 / 20, with num_trials : 68
# Found 11 / 20, with num_trials : 76
# Found 12 / 20, with num_trials : 86
# UPDATE: Found 12 / 20, with num_trials : 100
# Found 13 / 20, with num_trials : 101
# Found 14 / 20, with num_trials : 113
# Found 15 / 20, with num_trials : 124
# Found 16 / 20, with num_trials : 132
# Found 17 / 20, with num_trials : 140
# Found 18 / 20, with num_trials : 148
# Found 19 / 20, with num_trials : 151
# Found 20 / 20, with num_trials : 164
# Finished p=0.0199526231496888 with num_trials=165
# ------------------------------------------------------------------

# %%
def simulate(field, h, l, max_iter, num_failures, physical_error):

    results = []

    for p in physical_error:

        failures = 0
        num_trials = 0

        while failures < num_failures:
            # Generate syndrome
            n_qudits = h.shape[1]
            error = np.zeros(n_qudits, dtype=int)
            error_mask = np.random.rand(n_qudits) < p
            for i in np.where(error_mask)[0]:
                error[i] = np.random.randint(1, field.p)
            syndrome = (h @ error) % field.p

            # Construct error probability
            channel_prob_x = np.ones(n_qudits) * p

            x_prior = np.zeros((len(channel_prob_x), field.p), dtype=float)

            for i, prob in enumerate(channel_prob_x):
                x_prior[i, 0] = 1 - prob
                for j in range(1, field.p):
                    x_prior[i, j] = prob / (field.p - 1)

            # Decode
            # guessed_error, decoder_success, bp_success, posterior = belief_propagation(field, h, syndrome, x_prior, max_iter, debug=True)
            guessed_error, decoder_success, bp_success, posterior = bp_osd(field, h, syndrome, x_prior, max_iter, order=0, debug=True)
            error_difference = (error - guessed_error) % field.p
            logical_effect = (np.array(l) @ error_difference) % field.p

            # Check success
            # if np.any(logical_effect != 0) or not decoder_success:
            if np.any(logical_effect != 0):
                failures += 1
                print(f'Found {failures} / {num_failures}, with num_trials : {num_trials}')
            elif num_trials % 100 == 0:
                print(f'UPDATE: Found {failures} / {num_failures}, with num_trials : {num_trials}')

            num_trials += 1

        results.append(num_trials)

        print(f'Finished p={p} with num_trials={num_trials}')
        print('------------------------------------------------------------------')
    return results

# %%
def circ_simulate(field, bb, syndrome_circ, num_cycles, max_iter, num_failures, physical_error):

    results = []
    qubits_dict = bb.qubits_dict
    data_qubits = bb.data_qubits
    z_checks = bb.z_checks
    z_logicals = bb.z_logicals
    first_logical_row = bb.l * bb.m * (num_cycles + 2)
    k = len(z_logicals)

    for p in physical_error:

        error_rates = {'Meas': p, 'Prep': p, 'Idle': p, 'CNOT': p}
        # this step longgg
        print(f'Constructing decoding matrix for p={p}...')
        hx_eff, short_hx_eff, hz_eff, short_hz_eff, channel_prob_x, channel_prob_z = bb.construct_decoding_matrix(syndrome_circ, error_rates, num_cycles)
        hx_eff, short_hx_eff = hx_eff.toarray(), short_hx_eff.toarray()
        print(f'Constructed decoding matrix for p={p}')

        failures = 0
        num_trials = 0

        # Construct error probability
        x_prior = np.zeros((len(channel_prob_x), field.p), dtype=float)

        for i, prob in enumerate(channel_prob_x):
            x_prior[i, 0] = 1 - prob
            for j in range(1, field.p):
                x_prior[i, j] = prob / (field.p - 1)

        while failures < num_failures:

            # Generate noisy circuit
            noisy_circ, err_cnt = bb._generate_noisy_circuit(syndrome_circ * num_cycles, error_rates)

            x_syndrome_history, x_state, x_syndrome_map, x_err_count = bb._simulate_x_circuit(noisy_circ + syndrome_circ + syndrome_circ)
            x_state_data_qubits = [x_state[qubits_dict[qubit]] for qubit in data_qubits]
            x_syndrome_final_logical = (np.array(z_logicals) @ x_state_data_qubits) % field.p
            # Syndrome sparsification
            x_syndrome_history_copy = x_syndrome_history.copy()
            for check in z_checks:
                pos = x_syndrome_map[check]
                assert len(pos) == num_cycles + 2
                for row in range(1, num_cycles + 2):
                    x_syndrome_history[pos[row]] += x_syndrome_history_copy[pos[row-1]]
            x_syndrome_history %= field.p

            # Decode
            guessed_error, decoder_success, bp_success, posterior = bp_osd(field, short_hx_eff, x_syndrome_history, x_prior, max_iter, order=0, debug=True)

            # Check success
            x_syndrome_history_augmented_guessed = (hx_eff @ guessed_error) % field.p
            x_syndrome_final_logical_guessed = x_syndrome_history_augmented_guessed[first_logical_row: first_logical_row + k]
            x_success = np.array_equal(x_syndrome_final_logical_guessed, x_syndrome_final_logical)
            # if np.any(logical_effect != 0) or not decoder_success:
            if not x_success:
                failures += 1
                print(f'Found {failures} / {num_failures}, with num_trials : {num_trials}')
            elif num_trials % 100 == 0:
                print(f'UPDATE: Found {failures} / {num_failures}, with num_trials : {num_trials}')

            num_trials += 1

        results.append(num_trials)

        print(f'Finished p={p} with num_trials={num_trials}')
        print('------------------------------------------------------------------')
    return results

# %%
field = Field(2)
a = Polynomial(field, np.array([[1, 0], [1, 0]]))
b = Polynomial(field, np.array([[1, 1], [0, 0]]))
bb2 = BivariateBicycle(a, b, 3, 3, 1)
h2 = bb2.hx
l2 = bb2.x_logicals
bb25 = BivariateBicycle(a, b, 5, 5, 1)
h25 = bb25.hx
l25 = bb25.x_logicals
bb27 = BivariateBicycle(a, b, 7, 7, 1)
h27 = bb27.hx
l27 = bb27.x_logicals

field3 = Field(3)
a = Polynomial(field3, np.array([[1, 0], [-1, 0]]))
b = Polynomial(field3, np.array([[1, -1], [0, 0]]))
bb3 = BivariateBicycle(a, b, 3, 3, 1)
h3 = bb3.hx
l3 = bb3.x_logicals
bb35 = BivariateBicycle(a, b, 5, 5, 1)
h35 = bb35.hx
l35 = bb35.x_logicals
bb37 = BivariateBicycle(a, b, 7, 7, 1)
h37 = bb37.hx
l37 = bb37.x_logicals

field5 = Field(5)
a = Polynomial(field5, np.array([[1, 0], [-1, 0]]))
b = Polynomial(field5, np.array([[1, -1], [0, 0]]))
bb5 = BivariateBicycle(a, b, 3, 3, 1)
h5 = bb5.hx
l5 = bb5.x_logicals
bb55 = BivariateBicycle(a, b, 5, 5, 1)
h55 = bb55.hx
l55 = bb55.x_logicals
bb57 = BivariateBicycle(a, b, 7, 7, 1)
h57 = bb57.hx
l57 = bb57.x_logicals

# %%
max_iter = 300
num_failures = 3
long_physical_error = np.logspace(-2.7, -1, 10)
physical_error = np.flip(np.logspace(-1.7, -0.7, 10))
ext_physical_error = np.flip(np.logspace(-1, -0.8, 10))

# %%
x, y = Monomial(field, "x"), Monomial(field, "y")

a = y**3 + x + x**2
b = x**3 + y + y**2

bbq_72 = BivariateBicycle(a, b, 6, 6, 1)
h72 = bbq_72.hx
l72 = bbq_72.x_logicals

bbq_108 = BivariateBicycle(a, b, 6, 9, 1)
h108 = bbq_108.hx
l108 = bbq_108.x_logicals

bbq_144 = BivariateBicycle(a, b, 6, 12, 1)
h144 = bbq_144.hx
l144 = bbq_144.x_logicals

# %%
x, y = Monomial(field3, "x"), Monomial(field3, "y")

a = y**3 + x + x**2
b = x**3 + y + y**2

bbq_72_3 = BivariateBicycle(a, b, 6, 6, 1)
h72_3 = bbq_72.hx
l72_3 = bbq_72.x_logicals

bbq_108_3 = BivariateBicycle(a, b, 6, 9, 1)
h108_3 = bbq_108.hx
l108_3 = bbq_108.x_logicals

bbq_144_3 = BivariateBicycle(a, b, 6, 12, 1)
h144_3 = bbq_144.hx
l144_3 = bbq_144.x_logicals

# %%
x, y = Monomial(field5, "x"), Monomial(field5, "y")

a = y**3 + x + x**2
b = x**3 + y + y**2

bbq_72_5 = BivariateBicycle(a, b, 6, 6, 1)
h72_5 = bbq_72.hx
l72_5 = bbq_72.x_logicals

bbq_108_5 = BivariateBicycle(a, b, 6, 9, 1)
h108_5 = bbq_108.hx
l108_5 = bbq_108.x_logicals

bbq_144_5 = BivariateBicycle(a, b, 6, 12, 1)
h144_5 = bbq_144.hx
l144_5 = bbq_144.x_logicals

# %%
results = np.flip(simulate(field, h72, l72, max_iter, 20, physical_error))
# Out:
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 12
# Found 14 / 20, with num_trials : 13
# Found 15 / 20, with num_trials : 14
# Found 16 / 20, with num_trials : 15
# Found 17 / 20, with num_trials : 16
# Found 18 / 20, with num_trials : 17
# Found 19 / 20, with num_trials : 18
# Found 20 / 20, with num_trials : 19
# Finished p=0.19952623149688797 with num_trials=20
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 9
# Found 10 / 20, with num_trials : 10
# Found 11 / 20, with num_trials : 11
# Found 12 / 20, with num_trials : 12
# Found 13 / 20, with num_trials : 13
# Found 14 / 20, with num_trials : 14
# Found 15 / 20, with num_trials : 15
# Found 16 / 20, with num_trials : 16
# Found 17 / 20, with num_trials : 17
# Found 18 / 20, with num_trials : 18
# Found 19 / 20, with num_trials : 19
# Found 20 / 20, with num_trials : 20
# Finished p=0.15448591479026755 with num_trials=21
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 2
# Found 3 / 20, with num_trials : 3
# Found 4 / 20, with num_trials : 5
# Found 5 / 20, with num_trials : 7
# Found 6 / 20, with num_trials : 8
# Found 7 / 20, with num_trials : 9
# Found 8 / 20, with num_trials : 10
# Found 9 / 20, with num_trials : 11
# Found 10 / 20, with num_trials : 12
# Found 11 / 20, with num_trials : 13
# Found 12 / 20, with num_trials : 14
# Found 13 / 20, with num_trials : 15
# Found 14 / 20, with num_trials : 17
# Found 15 / 20, with num_trials : 18
# Found 16 / 20, with num_trials : 21
# Found 17 / 20, with num_trials : 22
# Found 18 / 20, with num_trials : 26
# Found 19 / 20, with num_trials : 27
# Found 20 / 20, with num_trials : 28
# Finished p=0.11961283330787534 with num_trials=29
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 3
# Found 2 / 20, with num_trials : 4
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: divide by zero encountered in divide
#   posteriors /= (
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:142: RuntimeWarning: invalid value encountered in divide
#   sub_posteriors = sub_posteriors / posterior
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:120: RuntimeWarning: invalid value encountered in divide
#   sub_convolutions = sub_convolutions / convolution
# Found 3 / 20, with num_trials : 5
# Found 4 / 20, with num_trials : 7
# Found 5 / 20, with num_trials : 8
# Found 6 / 20, with num_trials : 9
# Found 7 / 20, with num_trials : 10
# Found 8 / 20, with num_trials : 12
# Found 9 / 20, with num_trials : 16
# Found 10 / 20, with num_trials : 17
# Found 11 / 20, with num_trials : 19
# Found 12 / 20, with num_trials : 20
# Found 13 / 20, with num_trials : 22
# Found 14 / 20, with num_trials : 23
# Found 15 / 20, with num_trials : 26
# Found 16 / 20, with num_trials : 27
# Found 17 / 20, with num_trials : 29
# Found 18 / 20, with num_trials : 30
# Found 19 / 20, with num_trials : 31
# Found 20 / 20, with num_trials : 33
# Finished p=0.09261187281287937 with num_trials=34
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 4
# Found 3 / 20, with num_trials : 7
# Found 4 / 20, with num_trials : 10
# Found 5 / 20, with num_trials : 15
# Found 6 / 20, with num_trials : 16
# Found 7 / 20, with num_trials : 21
# Found 8 / 20, with num_trials : 29
# Found 9 / 20, with num_trials : 30
# Found 10 / 20, with num_trials : 32
# Found 11 / 20, with num_trials : 33
# Found 12 / 20, with num_trials : 35
# Found 13 / 20, with num_trials : 37
# Found 14 / 20, with num_trials : 39
# Found 15 / 20, with num_trials : 40
# Found 16 / 20, with num_trials : 43
# Found 17 / 20, with num_trials : 45
# Found 18 / 20, with num_trials : 46
# Found 19 / 20, with num_trials : 47
# Found 20 / 20, with num_trials : 48
# Finished p=0.07170600970409613 with num_trials=49
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 6
# Found 2 / 20, with num_trials : 8
# Found 3 / 20, with num_trials : 11
# Found 4 / 20, with num_trials : 13
# Found 5 / 20, with num_trials : 16
# Found 6 / 20, with num_trials : 17
# Found 7 / 20, with num_trials : 22
# Found 8 / 20, with num_trials : 33
# Found 9 / 20, with num_trials : 37
# Found 10 / 20, with num_trials : 40
# Found 11 / 20, with num_trials : 43
# Found 12 / 20, with num_trials : 55
# Found 13 / 20, with num_trials : 63
# Found 14 / 20, with num_trials : 73
# Found 15 / 20, with num_trials : 77
# Found 16 / 20, with num_trials : 83
# Found 17 / 20, with num_trials : 85
# Found 18 / 20, with num_trials : 88
# Found 19 / 20, with num_trials : 91
# Found 20 / 20, with num_trials : 100
# Finished p=0.05551935914386209 with num_trials=101
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 3
# Found 2 / 20, with num_trials : 12
# Found 3 / 20, with num_trials : 17
# Found 4 / 20, with num_trials : 33
# Found 5 / 20, with num_trials : 51
# Found 6 / 20, with num_trials : 57
# Found 7 / 20, with num_trials : 75
# Found 8 / 20, with num_trials : 78
# Found 9 / 20, with num_trials : 84
# Found 10 / 20, with num_trials : 88
# UPDATE: Found 10 / 20, with num_trials : 100
# Found 11 / 20, with num_trials : 107
# Found 12 / 20, with num_trials : 114
# Found 13 / 20, with num_trials : 123
# Found 14 / 20, with num_trials : 124
# Found 15 / 20, with num_trials : 125
# Found 16 / 20, with num_trials : 126
# Found 17 / 20, with num_trials : 135
# Found 18 / 20, with num_trials : 145
# Found 19 / 20, with num_trials : 160
# Found 20 / 20, with num_trials : 163
# Finished p=0.042986623470822764 with num_trials=164
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 56
# Found 2 / 20, with num_trials : 89
# UPDATE: Found 2 / 20, with num_trials : 100
# Found 3 / 20, with num_trials : 108
# Found 4 / 20, with num_trials : 113
# Found 5 / 20, with num_trials : 118
# Found 6 / 20, with num_trials : 142
# Found 7 / 20, with num_trials : 145
# Found 8 / 20, with num_trials : 151
# Found 9 / 20, with num_trials : 173
# Found 10 / 20, with num_trials : 189
# Found 11 / 20, with num_trials : 197
# UPDATE: Found 11 / 20, with num_trials : 200
# Found 12 / 20, with num_trials : 231
# Found 13 / 20, with num_trials : 300
# Found 14 / 20, with num_trials : 313
# Found 15 / 20, with num_trials : 317
# Found 16 / 20, with num_trials : 382
# Found 17 / 20, with num_trials : 399
# UPDATE: Found 17 / 20, with num_trials : 400
# Found 18 / 20, with num_trials : 420
# Found 19 / 20, with num_trials : 426
# Found 20 / 20, with num_trials : 432
# Finished p=0.033282981394546204 with num_trials=433
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 25
# Found 2 / 20, with num_trials : 48
# UPDATE: Found 2 / 20, with num_trials : 100
# Found 3 / 20, with num_trials : 132
# Found 4 / 20, with num_trials : 139
# Found 5 / 20, with num_trials : 151
# UPDATE: Found 5 / 20, with num_trials : 200
# Found 6 / 20, with num_trials : 211
# Found 7 / 20, with num_trials : 224
# Found 8 / 20, with num_trials : 260
# UPDATE: Found 8 / 20, with num_trials : 300
# Found 9 / 20, with num_trials : 365
# UPDATE: Found 9 / 20, with num_trials : 400
# Found 10 / 20, with num_trials : 451
# Found 11 / 20, with num_trials : 464
# UPDATE: Found 11 / 20, with num_trials : 500
# Found 12 / 20, with num_trials : 530
# Found 13 / 20, with num_trials : 562
# UPDATE: Found 13 / 20, with num_trials : 600
# UPDATE: Found 13 / 20, with num_trials : 700
# Found 14 / 20, with num_trials : 728
# Found 15 / 20, with num_trials : 776
# UPDATE: Found 15 / 20, with num_trials : 800
# Found 16 / 20, with num_trials : 864
# Found 17 / 20, with num_trials : 882
# UPDATE: Found 17 / 20, with num_trials : 900
# Found 18 / 20, with num_trials : 976
# UPDATE: Found 18 / 20, with num_trials : 1000
# Found 19 / 20, with num_trials : 1030
# Found 20 / 20, with num_trials : 1068
# Finished p=0.025769803745148787 with num_trials=1069
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 17
# UPDATE: Found 1 / 20, with num_trials : 100
# Found 2 / 20, with num_trials : 132
# Found 3 / 20, with num_trials : 184
# UPDATE: Found 3 / 20, with num_trials : 200
# UPDATE: Found 3 / 20, with num_trials : 300
# Found 4 / 20, with num_trials : 353
# UPDATE: Found 4 / 20, with num_trials : 400
# UPDATE: Found 4 / 20, with num_trials : 500
# Found 5 / 20, with num_trials : 521
# Found 6 / 20, with num_trials : 528
# Found 7 / 20, with num_trials : 546
# Found 8 / 20, with num_trials : 550
# UPDATE: Found 8 / 20, with num_trials : 600
# UPDATE: Found 8 / 20, with num_trials : 700
# Found 9 / 20, with num_trials : 786
# UPDATE: Found 9 / 20, with num_trials : 800
# Found 10 / 20, with num_trials : 884
# Found 11 / 20, with num_trials : 899
# UPDATE: Found 11 / 20, with num_trials : 900
# Found 12 / 20, with num_trials : 912
# UPDATE: Found 12 / 20, with num_trials : 1000
# UPDATE: Found 12 / 20, with num_trials : 1100
# UPDATE: Found 12 / 20, with num_trials : 1200
# Found 13 / 20, with num_trials : 1299
# UPDATE: Found 13 / 20, with num_trials : 1300
# Found 14 / 20, with num_trials : 1309
# UPDATE: Found 14 / 20, with num_trials : 1400
# UPDATE: Found 14 / 20, with num_trials : 1500
# Found 15 / 20, with num_trials : 1563
# Found 16 / 20, with num_trials : 1595
# UPDATE: Found 16 / 20, with num_trials : 1600
# Found 17 / 20, with num_trials : 1610
# Found 18 / 20, with num_trials : 1646
# UPDATE: Found 18 / 20, with num_trials : 1700
# UPDATE: Found 18 / 20, with num_trials : 1800
# UPDATE: Found 18 / 20, with num_trials : 1900
# Found 19 / 20, with num_trials : 1916
# Found 20 / 20, with num_trials : 1937
# Finished p=0.0199526231496888 with num_trials=1938
# ------------------------------------------------------------------

# %%
results = [1938, 1069, 433, 164, 101, 49, 34, 29, 21, 20]
results
# Out:
# [1938, 1069, 433, 164, 101, 49, 34, 29, 21, 20]

# %%
results
# Out:
# array([180,  50,  32,  34,  38,  19,   8,   5,   5,   5])

# %%
results = np.flip(simulate(field, h108, l108, max_iter, 20, physical_error))
# Out:
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 12
# Found 14 / 20, with num_trials : 13
# Found 15 / 20, with num_trials : 14
# Found 16 / 20, with num_trials : 15
# Found 17 / 20, with num_trials : 16
# Found 18 / 20, with num_trials : 17
# Found 19 / 20, with num_trials : 18
# Found 20 / 20, with num_trials : 19
# Finished p=0.19952623149688797 with num_trials=20
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 12
# Found 14 / 20, with num_trials : 13
# Found 15 / 20, with num_trials : 14
# Found 16 / 20, with num_trials : 15
# Found 17 / 20, with num_trials : 16
# Found 18 / 20, with num_trials : 17
# Found 19 / 20, with num_trials : 18
# Found 20 / 20, with num_trials : 19
# Finished p=0.15448591479026755 with num_trials=20
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 2
# Found 3 / 20, with num_trials : 3
# Found 4 / 20, with num_trials : 4
# Found 5 / 20, with num_trials : 6
# Found 6 / 20, with num_trials : 8
# Found 7 / 20, with num_trials : 9
# Found 8 / 20, with num_trials : 10
# Found 9 / 20, with num_trials : 11
# Found 10 / 20, with num_trials : 13
# Found 11 / 20, with num_trials : 14
# Found 12 / 20, with num_trials : 15
# Found 13 / 20, with num_trials : 16
# Found 14 / 20, with num_trials : 17
# Found 15 / 20, with num_trials : 19
# Found 16 / 20, with num_trials : 20
# Found 17 / 20, with num_trials : 21
# Found 18 / 20, with num_trials : 23
# Found 19 / 20, with num_trials : 24
# Found 20 / 20, with num_trials : 25
# Finished p=0.11961283330787534 with num_trials=26
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 3
# Found 4 / 20, with num_trials : 9
# Found 5 / 20, with num_trials : 10
# Found 6 / 20, with num_trials : 11
# Found 7 / 20, with num_trials : 13
# Found 8 / 20, with num_trials : 18
# Found 9 / 20, with num_trials : 19
# Found 10 / 20, with num_trials : 20
# Found 11 / 20, with num_trials : 22
# Found 12 / 20, with num_trials : 25
# Found 13 / 20, with num_trials : 29
# Found 14 / 20, with num_trials : 33
# Found 15 / 20, with num_trials : 34
# Found 16 / 20, with num_trials : 35
# Found 17 / 20, with num_trials : 37
# Found 18 / 20, with num_trials : 38
# Found 19 / 20, with num_trials : 41
# Found 20 / 20, with num_trials : 42
# Finished p=0.09261187281287937 with num_trials=43
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: divide by zero encountered in divide
#   posteriors /= (
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:142: RuntimeWarning: invalid value encountered in divide
#   sub_posteriors = sub_posteriors / posterior
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:120: RuntimeWarning: invalid value encountered in divide
#   sub_convolutions = sub_convolutions / convolution
# Found 1 / 20, with num_trials : 12
# Found 2 / 20, with num_trials : 15
# Found 3 / 20, with num_trials : 16
# Found 4 / 20, with num_trials : 19
# Found 5 / 20, with num_trials : 22
# Found 6 / 20, with num_trials : 23
# Found 7 / 20, with num_trials : 26
# Found 8 / 20, with num_trials : 39
# Found 9 / 20, with num_trials : 43
# Found 10 / 20, with num_trials : 45
# Found 11 / 20, with num_trials : 50
# Found 12 / 20, with num_trials : 59
# Found 13 / 20, with num_trials : 65
# Found 14 / 20, with num_trials : 69
# Found 15 / 20, with num_trials : 70
# Found 16 / 20, with num_trials : 75
# Found 17 / 20, with num_trials : 78
# Found 18 / 20, with num_trials : 82
# Found 19 / 20, with num_trials : 89
# Found 20 / 20, with num_trials : 94
# Finished p=0.07170600970409613 with num_trials=95
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 25
# Found 2 / 20, with num_trials : 37
# Found 3 / 20, with num_trials : 46
# UPDATE: Found 3 / 20, with num_trials : 100
# Found 4 / 20, with num_trials : 101
# Found 5 / 20, with num_trials : 112
# Found 6 / 20, with num_trials : 134
# Found 7 / 20, with num_trials : 140
# Found 8 / 20, with num_trials : 144
# Found 9 / 20, with num_trials : 165
# Found 10 / 20, with num_trials : 170
# Found 11 / 20, with num_trials : 175
# Found 12 / 20, with num_trials : 183
# UPDATE: Found 12 / 20, with num_trials : 200
# Found 13 / 20, with num_trials : 267
# Found 14 / 20, with num_trials : 280
# Found 15 / 20, with num_trials : 281
# UPDATE: Found 15 / 20, with num_trials : 300
# Found 16 / 20, with num_trials : 309
# Found 17 / 20, with num_trials : 327
# Found 18 / 20, with num_trials : 330
# Found 19 / 20, with num_trials : 331
# Found 20 / 20, with num_trials : 332
# Finished p=0.05551935914386209 with num_trials=333
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 11
# Found 2 / 20, with num_trials : 51
# Found 3 / 20, with num_trials : 83
# UPDATE: Found 3 / 20, with num_trials : 100
# Found 4 / 20, with num_trials : 108
# Found 5 / 20, with num_trials : 128
# UPDATE: Found 5 / 20, with num_trials : 200
# Found 6 / 20, with num_trials : 208
# Found 7 / 20, with num_trials : 214
# Found 8 / 20, with num_trials : 267
# UPDATE: Found 8 / 20, with num_trials : 300
# Found 9 / 20, with num_trials : 325
# Found 10 / 20, with num_trials : 385
# Found 11 / 20, with num_trials : 393
# UPDATE: Found 11 / 20, with num_trials : 400
# Found 12 / 20, with num_trials : 405
# Found 13 / 20, with num_trials : 458
# Found 14 / 20, with num_trials : 493
# UPDATE: Found 14 / 20, with num_trials : 500
# Found 15 / 20, with num_trials : 501
# Found 16 / 20, with num_trials : 513
# Found 17 / 20, with num_trials : 580
# Found 18 / 20, with num_trials : 586
# Found 19 / 20, with num_trials : 593
# UPDATE: Found 19 / 20, with num_trials : 600
# Found 20 / 20, with num_trials : 633
# Finished p=0.042986623470822764 with num_trials=634
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 14
# UPDATE: Found 1 / 20, with num_trials : 100
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:146: RuntimeWarning: invalid value encountered in divide
#   sub_posteriors / np.sum(sub_posteriors, axis=1)[:, np.newaxis]
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: invalid value encountered in divide
#   posteriors /= (
# Found 2 / 20, with num_trials : 137
# UPDATE: Found 2 / 20, with num_trials : 200
# UPDATE: Found 2 / 20, with num_trials : 300
# UPDATE: Found 2 / 20, with num_trials : 400
# UPDATE: Found 2 / 20, with num_trials : 500
# UPDATE: Found 2 / 20, with num_trials : 600
# Found 3 / 20, with num_trials : 624
# UPDATE: Found 3 / 20, with num_trials : 700
# UPDATE: Found 3 / 20, with num_trials : 800
# Found 4 / 20, with num_trials : 803
# Found 5 / 20, with num_trials : 885
# UPDATE: Found 5 / 20, with num_trials : 900
# Found 6 / 20, with num_trials : 920
# Found 7 / 20, with num_trials : 991
# UPDATE: Found 7 / 20, with num_trials : 1000
# UPDATE: Found 7 / 20, with num_trials : 1100
# UPDATE: Found 7 / 20, with num_trials : 1200
# Found 8 / 20, with num_trials : 1262
# Found 9 / 20, with num_trials : 1266
# UPDATE: Found 9 / 20, with num_trials : 1300
# Found 10 / 20, with num_trials : 1399
# UPDATE: Found 10 / 20, with num_trials : 1400
# Found 11 / 20, with num_trials : 1414
# UPDATE: Found 11 / 20, with num_trials : 1500
# UPDATE: Found 11 / 20, with num_trials : 1600
# UPDATE: Found 11 / 20, with num_trials : 1700
# UPDATE: Found 11 / 20, with num_trials : 1800
# Found 12 / 20, with num_trials : 1845
# UPDATE: Found 12 / 20, with num_trials : 1900
# UPDATE: Found 12 / 20, with num_trials : 2000
# UPDATE: Found 12 / 20, with num_trials : 2100
# UPDATE: Found 12 / 20, with num_trials : 2200
# Found 13 / 20, with num_trials : 2213
# Found 14 / 20, with num_trials : 2228
# Found 15 / 20, with num_trials : 2273
# UPDATE: Found 15 / 20, with num_trials : 2300
# UPDATE: Found 15 / 20, with num_trials : 2400
# UPDATE: Found 15 / 20, with num_trials : 2500
# Found 16 / 20, with num_trials : 2520
# Found 17 / 20, with num_trials : 2549
# UPDATE: Found 17 / 20, with num_trials : 2600
# UPDATE: Found 17 / 20, with num_trials : 2700
# Found 18 / 20, with num_trials : 2703
# Found 19 / 20, with num_trials : 2761
# UPDATE: Found 19 / 20, with num_trials : 2800
# Found 20 / 20, with num_trials : 2870
# Finished p=0.033282981394546204 with num_trials=2871
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 44
# UPDATE: Found 1 / 20, with num_trials : 100
# UPDATE: Found 1 / 20, with num_trials : 200
# UPDATE: Found 1 / 20, with num_trials : 300
# Found 2 / 20, with num_trials : 324
# UPDATE: Found 2 / 20, with num_trials : 400
# Found 3 / 20, with num_trials : 477
# UPDATE: Found 3 / 20, with num_trials : 500
# UPDATE: Found 3 / 20, with num_trials : 600
# UPDATE: Found 3 / 20, with num_trials : 700
# UPDATE: Found 3 / 20, with num_trials : 800
# UPDATE: Found 3 / 20, with num_trials : 900
# UPDATE: Found 3 / 20, with num_trials : 1000
# UPDATE: Found 3 / 20, with num_trials : 1100
# Found 4 / 20, with num_trials : 1150
# UPDATE: Found 4 / 20, with num_trials : 1200
# UPDATE: Found 4 / 20, with num_trials : 1300
# UPDATE: Found 4 / 20, with num_trials : 1400
# UPDATE: Found 4 / 20, with num_trials : 1500
# Found 5 / 20, with num_trials : 1521
# UPDATE: Found 5 / 20, with num_trials : 1600
# UPDATE: Found 5 / 20, with num_trials : 1700
# UPDATE: Found 5 / 20, with num_trials : 1800
# UPDATE: Found 5 / 20, with num_trials : 1900
# Found 6 / 20, with num_trials : 1929
# UPDATE: Found 6 / 20, with num_trials : 2000
# Found 7 / 20, with num_trials : 2076
# UPDATE: Found 7 / 20, with num_trials : 2100
# Found 8 / 20, with num_trials : 2152
# UPDATE: Found 8 / 20, with num_trials : 2200
# UPDATE: Found 8 / 20, with num_trials : 2300
# UPDATE: Found 8 / 20, with num_trials : 2400
# Found 9 / 20, with num_trials : 2432
# UPDATE: Found 9 / 20, with num_trials : 2500
# UPDATE: Found 9 / 20, with num_trials : 2600
# UPDATE: Found 9 / 20, with num_trials : 2700
# Found 10 / 20, with num_trials : 2734
# Found 11 / 20, with num_trials : 2771
# UPDATE: Found 11 / 20, with num_trials : 2800
# UPDATE: Found 11 / 20, with num_trials : 2900
# Found 12 / 20, with num_trials : 2925
# UPDATE: Found 12 / 20, with num_trials : 3000
# UPDATE: Found 12 / 20, with num_trials : 3100
# UPDATE: Found 12 / 20, with num_trials : 3200
# UPDATE: Found 12 / 20, with num_trials : 3300
# UPDATE: Found 12 / 20, with num_trials : 3400
# UPDATE: Found 12 / 20, with num_trials : 3500
# UPDATE: Found 12 / 20, with num_trials : 3600
# Found 13 / 20, with num_trials : 3687
# UPDATE: Found 13 / 20, with num_trials : 3700
# Found 14 / 20, with num_trials : 3715
# Found 15 / 20, with num_trials : 3727
# UPDATE: Found 15 / 20, with num_trials : 3800
# Found 16 / 20, with num_trials : 3854
# UPDATE: Found 16 / 20, with num_trials : 3900
# Found 17 / 20, with num_trials : 3911
# UPDATE: Found 17 / 20, with num_trials : 4000
# UPDATE: Found 17 / 20, with num_trials : 4100
# UPDATE: Found 17 / 20, with num_trials : 4200
# Found 18 / 20, with num_trials : 4201
# UPDATE: Found 18 / 20, with num_trials : 4300
# UPDATE: Found 18 / 20, with num_trials : 4400
# UPDATE: Found 18 / 20, with num_trials : 4500
# UPDATE: Found 18 / 20, with num_trials : 4600
# Found 19 / 20, with num_trials : 4660
# UPDATE: Found 19 / 20, with num_trials : 4700
# UPDATE: Found 19 / 20, with num_trials : 4800
# Found 20 / 20, with num_trials : 4828
# Finished p=0.025769803745148787 with num_trials=4829
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# UPDATE: Found 0 / 20, with num_trials : 100
# UPDATE: Found 0 / 20, with num_trials : 200
# UPDATE: Found 0 / 20, with num_trials : 300
# UPDATE: Found 0 / 20, with num_trials : 400
# UPDATE: Found 0 / 20, with num_trials : 500
# UPDATE: Found 0 / 20, with num_trials : 600
# UPDATE: Found 0 / 20, with num_trials : 700
# Found 1 / 20, with num_trials : 747
# UPDATE: Found 1 / 20, with num_trials : 800
# UPDATE: Found 1 / 20, with num_trials : 900
# UPDATE: Found 1 / 20, with num_trials : 1000
# UPDATE: Found 1 / 20, with num_trials : 1100
# Found 2 / 20, with num_trials : 1122
# UPDATE: Found 2 / 20, with num_trials : 1200
# UPDATE: Found 2 / 20, with num_trials : 1300
# UPDATE: Found 2 / 20, with num_trials : 1400
# UPDATE: Found 2 / 20, with num_trials : 1500
# Found 3 / 20, with num_trials : 1578
# UPDATE: Found 3 / 20, with num_trials : 1600
# UPDATE: Found 3 / 20, with num_trials : 1700
# UPDATE: Found 3 / 20, with num_trials : 1800
# Found 4 / 20, with num_trials : 1842
# UPDATE: Found 4 / 20, with num_trials : 1900
# UPDATE: Found 4 / 20, with num_trials : 2000
# UPDATE: Found 4 / 20, with num_trials : 2100
# UPDATE: Found 4 / 20, with num_trials : 2200
# UPDATE: Found 4 / 20, with num_trials : 2300
# UPDATE: Found 4 / 20, with num_trials : 2400
# UPDATE: Found 4 / 20, with num_trials : 2500
# UPDATE: Found 4 / 20, with num_trials : 2600
# UPDATE: Found 4 / 20, with num_trials : 2700
# UPDATE: Found 4 / 20, with num_trials : 2800
# UPDATE: Found 4 / 20, with num_trials : 2900
# UPDATE: Found 4 / 20, with num_trials : 3000
# UPDATE: Found 4 / 20, with num_trials : 3100
# Found 5 / 20, with num_trials : 3163
# Found 6 / 20, with num_trials : 3194
# UPDATE: Found 6 / 20, with num_trials : 3200
# UPDATE: Found 6 / 20, with num_trials : 3300
# UPDATE: Found 6 / 20, with num_trials : 3400
# UPDATE: Found 6 / 20, with num_trials : 3500
# Found 7 / 20, with num_trials : 3501
# UPDATE: Found 7 / 20, with num_trials : 3600
# Found 8 / 20, with num_trials : 3654
# UPDATE: Found 8 / 20, with num_trials : 3700
# Found 9 / 20, with num_trials : 3792
# UPDATE: Found 9 / 20, with num_trials : 3800
# UPDATE: Found 9 / 20, with num_trials : 3900
# UPDATE: Found 9 / 20, with num_trials : 4000
# UPDATE: Found 9 / 20, with num_trials : 4100
# UPDATE: Found 9 / 20, with num_trials : 4200
# UPDATE: Found 9 / 20, with num_trials : 4300
# Found 10 / 20, with num_trials : 4377
# UPDATE: Found 10 / 20, with num_trials : 4400
# Found 11 / 20, with num_trials : 4401
# UPDATE: Found 11 / 20, with num_trials : 4500
# UPDATE: Found 11 / 20, with num_trials : 4600
# UPDATE: Found 11 / 20, with num_trials : 4700
# UPDATE: Found 11 / 20, with num_trials : 4800
# Found 12 / 20, with num_trials : 4810
# UPDATE: Found 12 / 20, with num_trials : 4900
# UPDATE: Found 12 / 20, with num_trials : 5000
# UPDATE: Found 12 / 20, with num_trials : 5100
# Found 13 / 20, with num_trials : 5163
# UPDATE: Found 13 / 20, with num_trials : 5200
# UPDATE: Found 13 / 20, with num_trials : 5300
# UPDATE: Found 13 / 20, with num_trials : 5400
# UPDATE: Found 13 / 20, with num_trials : 5500
# UPDATE: Found 13 / 20, with num_trials : 5600
# UPDATE: Found 13 / 20, with num_trials : 5700
# UPDATE: Found 13 / 20, with num_trials : 5800
# UPDATE: Found 13 / 20, with num_trials : 5900
# UPDATE: Found 13 / 20, with num_trials : 6000
# UPDATE: Found 13 / 20, with num_trials : 6100
# UPDATE: Found 13 / 20, with num_trials : 6200
# UPDATE: Found 13 / 20, with num_trials : 6300
# UPDATE: Found 13 / 20, with num_trials : 6400
# UPDATE: Found 13 / 20, with num_trials : 6500
# UPDATE: Found 13 / 20, with num_trials : 6600
# UPDATE: Found 13 / 20, with num_trials : 6700
# UPDATE: Found 13 / 20, with num_trials : 6800
# UPDATE: Found 13 / 20, with num_trials : 6900
# UPDATE: Found 13 / 20, with num_trials : 7000
# UPDATE: Found 13 / 20, with num_trials : 7100
# Found 14 / 20, with num_trials : 7149
# UPDATE: Found 14 / 20, with num_trials : 7200
# Found 15 / 20, with num_trials : 7274
# UPDATE: Found 15 / 20, with num_trials : 7300
# Found 16 / 20, with num_trials : 7314
# UPDATE: Found 16 / 20, with num_trials : 7400
# UPDATE: Found 16 / 20, with num_trials : 7500
# UPDATE: Found 16 / 20, with num_trials : 7600
# Found 17 / 20, with num_trials : 7621
# UPDATE: Found 17 / 20, with num_trials : 7700
# UPDATE: Found 17 / 20, with num_trials : 7800
# UPDATE: Found 17 / 20, with num_trials : 7900
# Found 18 / 20, with num_trials : 7954
# UPDATE: Found 18 / 20, with num_trials : 8000
# UPDATE: Found 18 / 20, with num_trials : 8100
# UPDATE: Found 18 / 20, with num_trials : 8200
# UPDATE: Found 18 / 20, with num_trials : 8300
# UPDATE: Found 18 / 20, with num_trials : 8400
# UPDATE: Found 18 / 20, with num_trials : 8500
# UPDATE: Found 18 / 20, with num_trials : 8600
# UPDATE: Found 18 / 20, with num_trials : 8700
# UPDATE: Found 18 / 20, with num_trials : 8800
# Found 19 / 20, with num_trials : 8845
# UPDATE: Found 19 / 20, with num_trials : 8900
# UPDATE: Found 19 / 20, with num_trials : 9000
# UPDATE: Found 19 / 20, with num_trials : 9100
# UPDATE: Found 19 / 20, with num_trials : 9200
# UPDATE: Found 19 / 20, with num_trials : 9300
# Found 20 / 20, with num_trials : 9307
# Finished p=0.0199526231496888 with num_trials=9308
# ------------------------------------------------------------------

# %%
results
# Out:
# array([9308, 4829, 2871,  634,  333,   95,   43,   26,   20,   20])

# %%
results = np.flip(simulate(field, h144, l144, max_iter, 20, physical_error))
# Out:
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 12
# Found 14 / 20, with num_trials : 13
# Found 15 / 20, with num_trials : 14
# Found 16 / 20, with num_trials : 15
# Found 17 / 20, with num_trials : 16
# Found 18 / 20, with num_trials : 17
# Found 19 / 20, with num_trials : 18
# Found 20 / 20, with num_trials : 19
# Finished p=0.19952623149688797 with num_trials=20
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 12
# Found 14 / 20, with num_trials : 13
# Found 15 / 20, with num_trials : 14
# Found 16 / 20, with num_trials : 15
# Found 17 / 20, with num_trials : 16
# Found 18 / 20, with num_trials : 17
# Found 19 / 20, with num_trials : 18
# Found 20 / 20, with num_trials : 19
# Finished p=0.15448591479026755 with num_trials=20
# ------------------------------------------------------------------
# Found 1 / 20, with num_trials : 0
# Found 2 / 20, with num_trials : 1
# Found 3 / 20, with num_trials : 2
# Found 4 / 20, with num_trials : 3
# Found 5 / 20, with num_trials : 4
# Found 6 / 20, with num_trials : 5
# Found 7 / 20, with num_trials : 6
# Found 8 / 20, with num_trials : 7
# Found 9 / 20, with num_trials : 8
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: divide by zero encountered in divide
#   posteriors /= (
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:142: RuntimeWarning: invalid value encountered in divide
#   sub_posteriors = sub_posteriors / posterior
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:120: RuntimeWarning: invalid value encountered in divide
#   sub_convolutions = sub_convolutions / convolution
# Found 10 / 20, with num_trials : 9
# Found 11 / 20, with num_trials : 10
# Found 12 / 20, with num_trials : 11
# Found 13 / 20, with num_trials : 13
# Found 14 / 20, with num_trials : 14
# Found 15 / 20, with num_trials : 16
# Found 16 / 20, with num_trials : 17
# Found 17 / 20, with num_trials : 18
# Found 18 / 20, with num_trials : 19
# Found 19 / 20, with num_trials : 20
# Found 20 / 20, with num_trials : 21
# Finished p=0.11961283330787534 with num_trials=22
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 1
# Found 2 / 20, with num_trials : 2
# Found 3 / 20, with num_trials : 3
# Found 4 / 20, with num_trials : 5
# Found 5 / 20, with num_trials : 6
# Found 6 / 20, with num_trials : 7
# Found 7 / 20, with num_trials : 8
# Found 8 / 20, with num_trials : 9
# Found 9 / 20, with num_trials : 10
# Found 10 / 20, with num_trials : 12
# Found 11 / 20, with num_trials : 13
# Found 12 / 20, with num_trials : 14
# Found 13 / 20, with num_trials : 15
# Found 14 / 20, with num_trials : 18
# Found 15 / 20, with num_trials : 21
# Found 16 / 20, with num_trials : 24
# Found 17 / 20, with num_trials : 25
# Found 18 / 20, with num_trials : 28
# Found 19 / 20, with num_trials : 30
# Found 20 / 20, with num_trials : 31
# Finished p=0.09261187281287937 with num_trials=32
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 1
# Found 2 / 20, with num_trials : 4
# Found 3 / 20, with num_trials : 14
# Found 4 / 20, with num_trials : 15
# Found 5 / 20, with num_trials : 19
# Found 6 / 20, with num_trials : 22
# Found 7 / 20, with num_trials : 25
# Found 8 / 20, with num_trials : 26
# Found 9 / 20, with num_trials : 28
# Found 10 / 20, with num_trials : 42
# Found 11 / 20, with num_trials : 43
# Found 12 / 20, with num_trials : 45
# Found 13 / 20, with num_trials : 46
# Found 14 / 20, with num_trials : 66
# Found 15 / 20, with num_trials : 69
# Found 16 / 20, with num_trials : 71
# Found 17 / 20, with num_trials : 75
# Found 18 / 20, with num_trials : 78
# Found 19 / 20, with num_trials : 79
# Found 20 / 20, with num_trials : 82
# Finished p=0.07170600970409613 with num_trials=83
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 19
# Found 2 / 20, with num_trials : 22
# Found 3 / 20, with num_trials : 23
# Found 4 / 20, with num_trials : 28
# Found 5 / 20, with num_trials : 66
# Found 6 / 20, with num_trials : 88
# Found 7 / 20, with num_trials : 96
# UPDATE: Found 7 / 20, with num_trials : 100
# Found 8 / 20, with num_trials : 108
# Found 9 / 20, with num_trials : 142
# Found 10 / 20, with num_trials : 158
# Found 11 / 20, with num_trials : 165
# Found 12 / 20, with num_trials : 196
# Found 13 / 20, with num_trials : 199
# Found 14 / 20, with num_trials : 200
# Found 15 / 20, with num_trials : 206
# Found 16 / 20, with num_trials : 230
# Found 17 / 20, with num_trials : 237
# Found 18 / 20, with num_trials : 260
# Found 19 / 20, with num_trials : 268
# Found 20 / 20, with num_trials : 271
# Finished p=0.05551935914386209 with num_trials=272
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 46
# Found 2 / 20, with num_trials : 53
# Found 3 / 20, with num_trials : 64
# Found 4 / 20, with num_trials : 71
# Found 5 / 20, with num_trials : 77
# Found 6 / 20, with num_trials : 94
# Found 7 / 20, with num_trials : 96
# UPDATE: Found 7 / 20, with num_trials : 100
# Found 8 / 20, with num_trials : 107
# Found 9 / 20, with num_trials : 127
# Found 10 / 20, with num_trials : 144
# Found 11 / 20, with num_trials : 150
# Found 12 / 20, with num_trials : 151
# Found 13 / 20, with num_trials : 181
# UPDATE: Found 13 / 20, with num_trials : 200
# Found 14 / 20, with num_trials : 208
# UPDATE: Found 14 / 20, with num_trials : 300
# Found 15 / 20, with num_trials : 322
# Found 16 / 20, with num_trials : 325
# Found 17 / 20, with num_trials : 389
# Found 18 / 20, with num_trials : 399
# UPDATE: Found 18 / 20, with num_trials : 400
# Found 19 / 20, with num_trials : 433
# Found 20 / 20, with num_trials : 446
# Finished p=0.042986623470822764 with num_trials=447
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# Found 1 / 20, with num_trials : 8
# Found 2 / 20, with num_trials : 74
# UPDATE: Found 2 / 20, with num_trials : 100
# Found 3 / 20, with num_trials : 124
# Found 4 / 20, with num_trials : 126
# Found 5 / 20, with num_trials : 144
# Found 6 / 20, with num_trials : 177
# UPDATE: Found 6 / 20, with num_trials : 200
# Found 7 / 20, with num_trials : 271
# UPDATE: Found 7 / 20, with num_trials : 300
# Found 8 / 20, with num_trials : 321
# UPDATE: Found 8 / 20, with num_trials : 400
# Found 9 / 20, with num_trials : 434
# UPDATE: Found 9 / 20, with num_trials : 500
# Found 10 / 20, with num_trials : 561
# Found 11 / 20, with num_trials : 562
# Found 12 / 20, with num_trials : 564
# Found 13 / 20, with num_trials : 597
# UPDATE: Found 13 / 20, with num_trials : 600
# Found 14 / 20, with num_trials : 627
# Found 15 / 20, with num_trials : 633
# UPDATE: Found 15 / 20, with num_trials : 700
# UPDATE: Found 15 / 20, with num_trials : 800
# Found 16 / 20, with num_trials : 861
# Found 17 / 20, with num_trials : 873
# UPDATE: Found 17 / 20, with num_trials : 900
# Found 18 / 20, with num_trials : 918
# UPDATE: Found 18 / 20, with num_trials : 1000
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: invalid value encountered in divide
#   posteriors /= (
# Found 19 / 20, with num_trials : 1077
# UPDATE: Found 19 / 20, with num_trials : 1100
# Found 20 / 20, with num_trials : 1139
# Finished p=0.033282981394546204 with num_trials=1140
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# UPDATE: Found 0 / 20, with num_trials : 100
# UPDATE: Found 0 / 20, with num_trials : 200
# UPDATE: Found 0 / 20, with num_trials : 300
# UPDATE: Found 0 / 20, with num_trials : 400
# UPDATE: Found 0 / 20, with num_trials : 500
# Found 1 / 20, with num_trials : 517
# Found 2 / 20, with num_trials : 600
# UPDATE: Found 2 / 20, with num_trials : 700
# UPDATE: Found 2 / 20, with num_trials : 800
# Found 3 / 20, with num_trials : 863
# UPDATE: Found 3 / 20, with num_trials : 900
# Found 4 / 20, with num_trials : 973
# UPDATE: Found 4 / 20, with num_trials : 1000
# UPDATE: Found 4 / 20, with num_trials : 1100
# Found 5 / 20, with num_trials : 1110
# UPDATE: Found 5 / 20, with num_trials : 1200
# Found 6 / 20, with num_trials : 1231
# Found 7 / 20, with num_trials : 1242
# Found 8 / 20, with num_trials : 1266
# UPDATE: Found 8 / 20, with num_trials : 1300
# Found 9 / 20, with num_trials : 1370
# UPDATE: Found 9 / 20, with num_trials : 1400
# Found 10 / 20, with num_trials : 1407
# UPDATE: Found 10 / 20, with num_trials : 1500
# Found 11 / 20, with num_trials : 1586
# UPDATE: Found 11 / 20, with num_trials : 1600
# Found 12 / 20, with num_trials : 1675
# UPDATE: Found 12 / 20, with num_trials : 1700
# UPDATE: Found 12 / 20, with num_trials : 1800
# Found 13 / 20, with num_trials : 1811
# Found 14 / 20, with num_trials : 1827
# Found 15 / 20, with num_trials : 1890
# UPDATE: Found 15 / 20, with num_trials : 1900
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:146: RuntimeWarning: invalid value encountered in divide
#   sub_posteriors / np.sum(sub_posteriors, axis=1)[:, np.newaxis]
# Found 16 / 20, with num_trials : 1986
# UPDATE: Found 16 / 20, with num_trials : 2000
# UPDATE: Found 16 / 20, with num_trials : 2100
# Found 17 / 20, with num_trials : 2121
# UPDATE: Found 17 / 20, with num_trials : 2200
# Found 18 / 20, with num_trials : 2285
# Found 19 / 20, with num_trials : 2295
# UPDATE: Found 19 / 20, with num_trials : 2300
# UPDATE: Found 19 / 20, with num_trials : 2400
# UPDATE: Found 19 / 20, with num_trials : 2500
# UPDATE: Found 19 / 20, with num_trials : 2600
# Found 20 / 20, with num_trials : 2602
# Finished p=0.025769803745148787 with num_trials=2603
# ------------------------------------------------------------------
# UPDATE: Found 0 / 20, with num_trials : 0
# UPDATE: Found 0 / 20, with num_trials : 100
# Found 1 / 20, with num_trials : 146
# UPDATE: Found 1 / 20, with num_trials : 200
# Found 2 / 20, with num_trials : 206
# UPDATE: Found 2 / 20, with num_trials : 300
# UPDATE: Found 2 / 20, with num_trials : 400
# Found 3 / 20, with num_trials : 429
# UPDATE: Found 3 / 20, with num_trials : 500
# Found 4 / 20, with num_trials : 549
# Found 5 / 20, with num_trials : 574
# UPDATE: Found 5 / 20, with num_trials : 600
# Found 6 / 20, with num_trials : 636
# UPDATE: Found 6 / 20, with num_trials : 700
# Found 7 / 20, with num_trials : 710
# UPDATE: Found 7 / 20, with num_trials : 800
# Found 8 / 20, with num_trials : 853
# UPDATE: Found 8 / 20, with num_trials : 900
# Found 9 / 20, with num_trials : 926
# UPDATE: Found 9 / 20, with num_trials : 1000
# UPDATE: Found 9 / 20, with num_trials : 1100
# UPDATE: Found 9 / 20, with num_trials : 1200
# UPDATE: Found 9 / 20, with num_trials : 1300
# UPDATE: Found 9 / 20, with num_trials : 1400
# Found 10 / 20, with num_trials : 1491
# UPDATE: Found 10 / 20, with num_trials : 1500
# UPDATE: Found 10 / 20, with num_trials : 1600
# UPDATE: Found 10 / 20, with num_trials : 1700
# UPDATE: Found 10 / 20, with num_trials : 1800
# Found 11 / 20, with num_trials : 1833
# UPDATE: Found 11 / 20, with num_trials : 1900
# Found 12 / 20, with num_trials : 1972
# UPDATE: Found 12 / 20, with num_trials : 2000
# UPDATE: Found 12 / 20, with num_trials : 2100
# UPDATE: Found 12 / 20, with num_trials : 2200
# UPDATE: Found 12 / 20, with num_trials : 2300
# Found 13 / 20, with num_trials : 2369
# UPDATE: Found 13 / 20, with num_trials : 2400
# Found 14 / 20, with num_trials : 2467
# UPDATE: Found 14 / 20, with num_trials : 2500
# Found 15 / 20, with num_trials : 2577
# UPDATE: Found 15 / 20, with num_trials : 2600
# Found 16 / 20, with num_trials : 2619
# Found 17 / 20, with num_trials : 2627
# Found 18 / 20, with num_trials : 2635
# Found 19 / 20, with num_trials : 2668
# UPDATE: Found 19 / 20, with num_trials : 2700
# UPDATE: Found 19 / 20, with num_trials : 2800
# UPDATE: Found 19 / 20, with num_trials : 2900
# Found 20 / 20, with num_trials : 2967
# Finished p=0.0199526231496888 with num_trials=2968
# ------------------------------------------------------------------

# %%
results
# Out:
# array([2968, 2603, 1140,  447,  272,   83,   32,   22,   20,   20])

# %%
x_order = ['Idle', 0, 3, 1, 2]
z_order = [0, 3, 1, 2, 'Idle']
max_iter = 100

num_cycles = 5
circ = bb25.construct_sm_circuit(x_order, z_order)

# %%
circ_physical_error = np.flip(np.logspace(-2.3, -2, 10))
circ_physical_error
# Out:
# array([0.01      , 0.00926119, 0.00857696, 0.00794328, 0.00735642,
#        0.00681292, 0.00630957, 0.00584341, 0.0054117 , 0.00501187])

# %%
results = circ_simulate(Field(2), bb25, circ, num_cycles, max_iter, 5, circ_physical_error)
# Out:
# Constructing decoding matrix for p=0.01...
# Constructed decoding matrix for p=0.01
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:142: RuntimeWarning: invalid value encountered in divide
#   sub_posteriors = sub_posteriors / posterior
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: divide by zero encountered in divide
#   posteriors /= (
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: invalid value encountered in divide
#   posteriors /= (
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:120: RuntimeWarning: invalid value encountered in divide
#   sub_convolutions = sub_convolutions / convolution
# Found 1 / 5, with num_trials : 0
# Found 2 / 5, with num_trials : 1
# Found 3 / 5, with num_trials : 2
# Found 4 / 5, with num_trials : 5
# Found 5 / 5, with num_trials : 7
# Finished p=0.01 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.009261187281287938...
# Constructed decoding matrix for p=0.009261187281287938
# Found 1 / 5, with num_trials : 0
# Found 2 / 5, with num_trials : 3
# Found 3 / 5, with num_trials : 4
# Found 4 / 5, with num_trials : 5
# Found 5 / 5, with num_trials : 7
# Finished p=0.009261187281287938 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.008576958985908946...
# Constructed decoding matrix for p=0.008576958985908946
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 1
# Found 2 / 5, with num_trials : 3
# Found 3 / 5, with num_trials : 5
# Found 4 / 5, with num_trials : 6
# Found 5 / 5, with num_trials : 7
# Finished p=0.008576958985908946 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.007943282347242814...
# Constructed decoding matrix for p=0.007943282347242814
# Found 1 / 5, with num_trials : 0
# Found 2 / 5, with num_trials : 1
# Found 3 / 5, with num_trials : 3
# Found 4 / 5, with num_trials : 4
# Found 5 / 5, with num_trials : 5
# Finished p=0.007943282347242814 with num_trials=6
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.007356422544596414...
# Constructed decoding matrix for p=0.007356422544596414
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 4
# Found 2 / 5, with num_trials : 5
# Found 3 / 5, with num_trials : 7
# Found 4 / 5, with num_trials : 8
# Found 5 / 5, with num_trials : 9
# Finished p=0.007356422544596414 with num_trials=10
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.006812920690579615...
# Constructed decoding matrix for p=0.006812920690579615
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 5
# Found 2 / 5, with num_trials : 7
# Found 3 / 5, with num_trials : 9
# Found 4 / 5, with num_trials : 11
# Found 5 / 5, with num_trials : 12
# Finished p=0.006812920690579615 with num_trials=13
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.006309573444801936...
# Constructed decoding matrix for p=0.006309573444801936
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 1
# Found 2 / 5, with num_trials : 2
# Found 3 / 5, with num_trials : 3
# Found 4 / 5, with num_trials : 4
# Found 5 / 5, with num_trials : 7
# Finished p=0.006309573444801936 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.005843414133735175...
# Constructed decoding matrix for p=0.005843414133735175
# Found 1 / 5, with num_trials : 0
# Found 2 / 5, with num_trials : 5
# Found 3 / 5, with num_trials : 8
# Found 4 / 5, with num_trials : 12
# Found 5 / 5, with num_trials : 13
# Finished p=0.005843414133735175 with num_trials=14
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.0054116952654646375...
# Constructed decoding matrix for p=0.0054116952654646375
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 3
# Found 2 / 5, with num_trials : 4
# Found 3 / 5, with num_trials : 5
# Found 4 / 5, with num_trials : 6
# Found 5 / 5, with num_trials : 7
# Finished p=0.0054116952654646375 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.005011872336272725...
# Constructed decoding matrix for p=0.005011872336272725
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 1
# Found 2 / 5, with num_trials : 2
# Found 3 / 5, with num_trials : 3
# Found 4 / 5, with num_trials : 5
# Found 5 / 5, with num_trials : 7
# Finished p=0.005011872336272725 with num_trials=8
# ------------------------------------------------------------------

# %%
# d = 5

results
# Out:
# [8, 8, 8, 6, 10, 13, 8, 14, 8, 8]

# %%
# d = 3

results
# Out:
# [12, 23, 22, 22, 16, 20, 6, 21, 28, 28]

# %%
5/28
# Out:
# 0.17857142857142858

# %%
results = np.flip(simulate(5, h55, l55, max_iter, 50, ext_physical_error))

# %%
results

# %%
results = np.flip(simulate(5, h57, l57, max_iter, 50, ext_physical_error))

# %%
results

# %%
results = np.flip(simulate(5, h5, l5, max_iter, 50, ext_physical_error))

# %%
results

# %%
results = np.flip(simulate(5, h55, l55, max_iter, 50, ext_physical_error))

# %%
results

# %%
results = np.flip(simulate(5, h57, l57, max_iter, 50, ext_physical_error))

# %%
results

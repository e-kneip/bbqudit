# %% [markdown]
# # Simulation

# %%
from bbq.decoder import bp_osd, Decoder, TempDecoder
import numpy as np
from ldpc import BpDecoder, bposd_decoder
from bbq.polynomial import Polynomial, Monomial
from bbq.bbq_code import BivariateBicycle
from bbq.field import Field
from bbq.parameters import bp_distance

# %% [markdown]
# ## Simulation functions

# %%
# Using ldpc package

my_bp_method = "minimum_sum"
my_max_iter = 300
my_osd_method = "osd_0"
my_osd_order = 0
my_ms_scaling_factor = 0

def simulate_ldpc(field, h, l, max_iter, num_failures, physical_error, my_bp_method = "minimum_sum", my_max_iter = 300, my_osd_method = "osd_0", my_osd_order = 0, my_ms_scaling_factor = 0):

    results = []

    for p in physical_error:

        failures = 0
        num_trials = 0

        n_qudits = h.shape[1]

        channel_prob_x = np.ones(n_qudits) * p

        x_prior = np.zeros((len(channel_prob_x), field.p), dtype=float)

        for i, prob in enumerate(channel_prob_x):
            x_prior[i, 0] = 1 - prob
            for j in range(1, field.p):
                x_prior[i, j] = prob / (field.p - 1)

        bpd = bposd_decoder(
            h,
            channel_probs = list(x_prior[:, 1]),
            max_iter = my_max_iter,
            bp_method = my_bp_method,
            ms_scaling_factor = my_ms_scaling_factor,
            osd_method = my_osd_method,
            osd_order = my_osd_order
            )

        while failures < num_failures:
            # Generate syndrome
            error = np.zeros(n_qudits, dtype=int)
            error_mask = np.random.rand(n_qudits) < p
            for i in np.where(error_mask)[0]:
                error[i] = np.random.randint(1, field.p)
            syndrome = (h @ error) % field.p

            # Decode
            # guessed_error, decoder_success, bp_success, posterior = belief_propagation(field, h, syndrome, x_prior, max_iter, debug=True)
            bpd.decode(syndrome)
            guessed_error = bpd.osdw_decoding
            error_difference = (error - guessed_error) % field.p
            logical_effect = (np.array(l) @ error_difference) % field.p

            # Check success
            # if np.any(logical_effect != 0) or not decoder_success:
            if np.any(logical_effect != 0):
                failures += 1
                print(f'Found {failures} / {num_failures}, with num_trials : {num_trials}')
            elif num_trials % 100 == 0:
                print(f'UPDATE: Found {failures} / {num_failures}, with num_trials : {num_trials}')

            num_trials += 1

        results.append(num_trials)

        print(f'Finished p={p} with num_trials={num_trials}')
        print('------------------------------------------------------------------')
    return results

# %%
# Using bbq package

def simulate(field, h, l, max_iter, num_failures, physical_error):

    results = []

    for p in physical_error:

        failures = 0
        num_trials = 0

        while failures < num_failures:
            # Generate syndrome
            n_qudits = h.shape[1]
            error = np.zeros(n_qudits, dtype=int)
            error_mask = np.random.rand(n_qudits) < p
            for i in np.where(error_mask)[0]:
                error[i] = np.random.randint(1, field.p)
            syndrome = (h @ error) % field.p

            # Construct error probability
            channel_prob_x = np.ones(n_qudits) * p

            x_prior = np.zeros((len(channel_prob_x), field.p), dtype=float)

            for i, prob in enumerate(channel_prob_x):
                x_prior[i, 0] = 1 - prob
                for j in range(1, field.p):
                    x_prior[i, j] = prob / (field.p - 1)

            # Decode
            # guessed_error, decoder_success, bp_success, posterior = belief_propagation(field, h, syndrome, x_prior, max_iter, debug=True)
            guessed_error, decoder_success, bp_success, posterior = bp_osd(field, h, syndrome, x_prior, max_iter, order=0, debug=True)
            error_difference = (error - guessed_error) % field.p
            logical_effect = (np.array(l) @ error_difference) % field.p

            # Check success
            # if np.any(logical_effect != 0) or not decoder_success:
            if np.any(logical_effect != 0):
                failures += 1
                print(f'Found {failures} / {num_failures}, with num_trials : {num_trials}')
            elif num_trials % 100 == 0:
                print(f'UPDATE: Found {failures} / {num_failures}, with num_trials : {num_trials}')

            num_trials += 1

        results.append(num_trials)

        print(f'Finished p={p} with num_trials={num_trials}')
        print('------------------------------------------------------------------')
    return results

# %%
# Circuit-level simulation using bbq package

def circ_simulate(field, bb, syndrome_circ, num_cycles, max_iter, num_failures, physical_error):

    results = []
    qudits_dict = bb.qudits_dict
    data_qudits = bb.data_qudits
    z_checks = bb.z_checks
    z_logicals = bb.z_logicals
    first_logical_row = bb.l * bb.m * (num_cycles + 2)
    k = len(z_logicals)

    for p in physical_error:

        error_rates = {'Meas': p, 'Prep': p, 'Idle': p, 'CNOT': p}
        # this step longgg
        print(f'Constructing decoding matrix for p={p}...')
        hx_eff, short_hx_eff, hz_eff, short_hz_eff, channel_prob_x, channel_prob_z = bb.construct_decoding_matrix(syndrome_circ, error_rates, num_cycles)
        hx_eff, short_hx_eff = hx_eff.toarray(), short_hx_eff.toarray()
        print(f'Constructed decoding matrix for p={p}')

        failures = 0
        num_trials = 0

        # Construct error probability
        x_prior = np.zeros((len(channel_prob_x), field.p), dtype=float)

        for i, prob in enumerate(channel_prob_x):
            x_prior[i, 0] = 1 - prob
            for j in range(1, field.p):
                x_prior[i, j] = prob / (field.p - 1)

        while failures < num_failures:

            # Generate noisy circuit
            noisy_circ, err_cnt = bb._generate_noisy_circuit(syndrome_circ * num_cycles, error_rates)

            x_syndrome_history, x_state, x_syndrome_map, x_err_count = bb._simulate_x_circuit(noisy_circ + syndrome_circ + syndrome_circ)
            x_state_data_qudits = [x_state[qudits_dict[qudit]] for qudit in data_qudits]
            x_syndrome_final_logical = (np.array(z_logicals) @ x_state_data_qudits) % field.p
            # Syndrome sparsification
            x_syndrome_history_copy = x_syndrome_history.copy()
            for check in z_checks:
                pos = x_syndrome_map[check]
                assert len(pos) == num_cycles + 2
                for row in range(1, num_cycles + 2):
                    x_syndrome_history[pos[row]] += x_syndrome_history_copy[pos[row-1]]
            x_syndrome_history %= field.p

            # Decode
            guessed_error, decoder_success, bp_success, posterior = bp_osd(field, short_hx_eff, x_syndrome_history, x_prior, max_iter, order=0, debug=True)

            # Check success
            x_syndrome_history_augmented_guessed = (hx_eff @ guessed_error) % field.p
            x_syndrome_final_logical_guessed = x_syndrome_history_augmented_guessed[first_logical_row: first_logical_row + k]
            x_success = np.array_equal(x_syndrome_final_logical_guessed, x_syndrome_final_logical)
            # if np.any(logical_effect != 0) or not decoder_success:
            if not x_success:
                failures += 1
                print(f'Found {failures} / {num_failures}, with num_trials : {num_trials}')
            elif num_trials % 100 == 0:
                print(f'UPDATE: Found {failures} / {num_failures}, with num_trials : {num_trials}')

            num_trials += 1

        results.append(num_trials)

        print(f'Finished p={p} with num_trials={num_trials}')
        print('------------------------------------------------------------------')
    return results

# %% [markdown]
# ## Code set up

# %%
field = Field(2)
a = Polynomial(field, np.array([[1, 0], [1, 0]]))
b = Polynomial(field, np.array([[1, 1], [0, 0]]))
bb2 = BivariateBicycle(a, b, 3, 3, 1)
h2 = bb2.hx
l2 = bb2.x_logicals
bb25 = BivariateBicycle(a, b, 5, 5, 1)
h25 = bb25.hx
l25 = bb25.x_logicals
bb27 = BivariateBicycle(a, b, 7, 7, 1)
h27 = bb27.hx
l27 = bb27.x_logicals

field3 = Field(3)
a = Polynomial(field3, np.array([[1, 0], [-1, 0]]))
b = Polynomial(field3, np.array([[1, -1], [0, 0]]))
bb3 = BivariateBicycle(a, b, 3, 3, 1)
h3 = bb3.hx
l3 = bb3.x_logicals
bb35 = BivariateBicycle(a, b, 5, 5, 1)
h35 = bb35.hx
l35 = bb35.x_logicals
bb37 = BivariateBicycle(a, b, 7, 7, 1)
h37 = bb37.hx
l37 = bb37.x_logicals

field5 = Field(5)
a = Polynomial(field5, np.array([[1, 0], [-1, 0]]))
b = Polynomial(field5, np.array([[1, -1], [0, 0]]))
bb5 = BivariateBicycle(a, b, 3, 3, 1)
h5 = bb5.hx
l5 = bb5.x_logicals
bb55 = BivariateBicycle(a, b, 5, 5, 1)
h55 = bb55.hx
l55 = bb55.x_logicals
bb57 = BivariateBicycle(a, b, 7, 7, 1)
h57 = bb57.hx
l57 = bb57.x_logicals

# %%
max_iter = 300
num_failures = 3
long_physical_error = np.logspace(-2.7, -1, 10)
physical_error = np.flip(np.logspace(-1.7, -0.7, 10))
ext_physical_error = np.flip(np.logspace(-1, -0.8, 10))

# %%
x, y = Monomial(field, "x"), Monomial(field, "y")

a = y**3 + x + x**2
b = x**3 + y + y**2

bbq_72 = BivariateBicycle(a, b, 6, 6, 1)
h72 = bbq_72.hx
l72 = bbq_72.x_logicals

bbq_108 = BivariateBicycle(a, b, 6, 9, 1)
h108 = bbq_108.hx
l108 = bbq_108.x_logicals

bbq_144 = BivariateBicycle(a, b, 6, 12, 1)
h144 = bbq_144.hx
l144 = bbq_144.x_logicals

# %%
x, y = Monomial(field3, "x"), Monomial(field3, "y")

a = y**3 + x + x**2
b = x**3 + y + y**2

bbq_72_3 = BivariateBicycle(a, b, 6, 6, 1)
h72_3 = bbq_72.hx
l72_3 = bbq_72.x_logicals

bbq_108_3 = BivariateBicycle(a, b, 6, 9, 1)
h108_3 = bbq_108.hx
l108_3 = bbq_108.x_logicals

bbq_144_3 = BivariateBicycle(a, b, 6, 12, 1)
h144_3 = bbq_144.hx
l144_3 = bbq_144.x_logicals

# %%
x, y = Monomial(field5, "x"), Monomial(field5, "y")

a = y**3 + x + x**2
b = x**3 + y + y**2

bbq_72_5 = BivariateBicycle(a, b, 6, 6, 1)
h72_5 = bbq_72.hx
l72_5 = bbq_72.x_logicals

bbq_108_5 = BivariateBicycle(a, b, 6, 9, 1)
h108_5 = bbq_108.hx
l108_5 = bbq_108.x_logicals

bbq_144_5 = BivariateBicycle(a, b, 6, 12, 1)
h144_5 = bbq_144.hx
l144_5 = bbq_144.x_logicals

# %% [markdown]
# ## Simulations

# %%
results = np.flip(simulate_ldpc(field, h72, l72, max_iter, 500, physical_error))
# Out:
# Found 1 / 500, with num_trials : 0
# Found 2 / 500, with num_trials : 1
# Found 3 / 500, with num_trials : 2
# Found 4 / 500, with num_trials : 3
# Found 5 / 500, with num_trials : 4
# Found 6 / 500, with num_trials : 5
# Found 7 / 500, with num_trials : 6
# Found 8 / 500, with num_trials : 7
# Found 9 / 500, with num_trials : 8
# Found 10 / 500, with num_trials : 9
# Found 11 / 500, with num_trials : 10
# Found 12 / 500, with num_trials : 11
# Found 13 / 500, with num_trials : 12
# Found 14 / 500, with num_trials : 13
# Found 15 / 500, with num_trials : 14
# Found 16 / 500, with num_trials : 15
# Found 17 / 500, with num_trials : 16
# Found 18 / 500, with num_trials : 17
# Found 19 / 500, with num_trials : 18
# Found 20 / 500, with num_trials : 19
# Found 21 / 500, with num_trials : 20
# Found 22 / 500, with num_trials : 21
# Found 23 / 500, with num_trials : 22
# Found 24 / 500, with num_trials : 23
# Found 25 / 500, with num_trials : 24
# Found 26 / 500, with num_trials : 25
# Found 27 / 500, with num_trials : 26
# Found 28 / 500, with num_trials : 27
# Found 29 / 500, with num_trials : 28
# Found 30 / 500, with num_trials : 29
# Found 31 / 500, with num_trials : 30
# Found 32 / 500, with num_trials : 31
# Found 33 / 500, with num_trials : 32
# Found 34 / 500, with num_trials : 33
# Found 35 / 500, with num_trials : 34
# Found 36 / 500, with num_trials : 35
# Found 37 / 500, with num_trials : 36
# Found 38 / 500, with num_trials : 37
# Found 39 / 500, with num_trials : 38
# Found 40 / 500, with num_trials : 39
# Found 41 / 500, with num_trials : 40
# Found 42 / 500, with num_trials : 41
# Found 43 / 500, with num_trials : 42
# Found 44 / 500, with num_trials : 43
# Found 45 / 500, with num_trials : 44
# Found 46 / 500, with num_trials : 45
# Found 47 / 500, with num_trials : 46
# Found 48 / 500, with num_trials : 47
# Found 49 / 500, with num_trials : 48
# Found 50 / 500, with num_trials : 49
# Found 51 / 500, with num_trials : 50
# Found 52 / 500, with num_trials : 51
# Found 53 / 500, with num_trials : 52
# Found 54 / 500, with num_trials : 53
# Found 55 / 500, with num_trials : 54
# Found 56 / 500, with num_trials : 55
# Found 57 / 500, with num_trials : 56
# Found 58 / 500, with num_trials : 57
# Found 59 / 500, with num_trials : 58
# Found 60 / 500, with num_trials : 59
# Found 61 / 500, with num_trials : 60
# Found 62 / 500, with num_trials : 61
# Found 63 / 500, with num_trials : 62
# Found 64 / 500, with num_trials : 63
# Found 65 / 500, with num_trials : 64
# Found 66 / 500, with num_trials : 65
# Found 67 / 500, with num_trials : 66
# Found 68 / 500, with num_trials : 67
# Found 69 / 500, with num_trials : 68
# Found 70 / 500, with num_trials : 69
# Found 71 / 500, with num_trials : 70
# Found 72 / 500, with num_trials : 71
# Found 73 / 500, with num_trials : 72
# Found 74 / 500, with num_trials : 73
# Found 75 / 500, with num_trials : 74
# Found 76 / 500, with num_trials : 75
# Found 77 / 500, with num_trials : 76
# Found 78 / 500, with num_trials : 77
# Found 79 / 500, with num_trials : 78
# Found 80 / 500, with num_trials : 79
# Found 81 / 500, with num_trials : 80
# Found 82 / 500, with num_trials : 81
# Found 83 / 500, with num_trials : 82
# Found 84 / 500, with num_trials : 83
# Found 85 / 500, with num_trials : 84
# Found 86 / 500, with num_trials : 85
# Found 87 / 500, with num_trials : 86
# Found 88 / 500, with num_trials : 87
# Found 89 / 500, with num_trials : 88
# Found 90 / 500, with num_trials : 89
# Found 91 / 500, with num_trials : 90
# Found 92 / 500, with num_trials : 91
# Found 93 / 500, with num_trials : 92
# Found 94 / 500, with num_trials : 93
# Found 95 / 500, with num_trials : 94
# Found 96 / 500, with num_trials : 95
# Found 97 / 500, with num_trials : 96
# Found 98 / 500, with num_trials : 97
# Found 99 / 500, with num_trials : 98
# Found 100 / 500, with num_trials : 99
# Found 101 / 500, with num_trials : 100
# Found 102 / 500, with num_trials : 101
# Found 103 / 500, with num_trials : 102
# Found 104 / 500, with num_trials : 103
# Found 105 / 500, with num_trials : 104
# Found 106 / 500, with num_trials : 105
# Found 107 / 500, with num_trials : 106
# Found 108 / 500, with num_trials : 107
# Found 109 / 500, with num_trials : 108
# Found 110 / 500, with num_trials : 109
# Found 111 / 500, with num_trials : 110
# Found 112 / 500, with num_trials : 111
# Found 113 / 500, with num_trials : 112
# Found 114 / 500, with num_trials : 113
# Found 115 / 500, with num_trials : 114
# Found 116 / 500, with num_trials : 115
# Found 117 / 500, with num_trials : 116
# Found 118 / 500, with num_trials : 117
# Found 119 / 500, with num_trials : 118
# Found 120 / 500, with num_trials : 119
# Found 121 / 500, with num_trials : 120
# Found 122 / 500, with num_trials : 121
# Found 123 / 500, with num_trials : 122
# Found 124 / 500, with num_trials : 123
# Found 125 / 500, with num_trials : 124
# Found 126 / 500, with num_trials : 125
# Found 127 / 500, with num_trials : 126
# Found 128 / 500, with num_trials : 127
# Found 129 / 500, with num_trials : 128
# Found 130 / 500, with num_trials : 129
# Found 131 / 500, with num_trials : 130
# Found 132 / 500, with num_trials : 131
# Found 133 / 500, with num_trials : 132
# Found 134 / 500, with num_trials : 133
# Found 135 / 500, with num_trials : 134
# Found 136 / 500, with num_trials : 135
# Found 137 / 500, with num_trials : 136
# Found 138 / 500, with num_trials : 137
# Found 139 / 500, with num_trials : 138
# Found 140 / 500, with num_trials : 139
# Found 141 / 500, with num_trials : 140
# Found 142 / 500, with num_trials : 141
# Found 143 / 500, with num_trials : 142
# Found 144 / 500, with num_trials : 143
# Found 145 / 500, with num_trials : 144
# Found 146 / 500, with num_trials : 145
# Found 147 / 500, with num_trials : 146
# Found 148 / 500, with num_trials : 147
# Found 149 / 500, with num_trials : 148
# Found 150 / 500, with num_trials : 149
# Found 151 / 500, with num_trials : 150
# Found 152 / 500, with num_trials : 151
# Found 153 / 500, with num_trials : 152
# Found 154 / 500, with num_trials : 153
# Found 155 / 500, with num_trials : 154
# Found 156 / 500, with num_trials : 155
# Found 157 / 500, with num_trials : 156
# Found 158 / 500, with num_trials : 157
# Found 159 / 500, with num_trials : 158
# Found 160 / 500, with num_trials : 159
# Found 161 / 500, with num_trials : 160
# Found 162 / 500, with num_trials : 161
# Found 163 / 500, with num_trials : 162
# Found 164 / 500, with num_trials : 163
# Found 165 / 500, with num_trials : 164
# Found 166 / 500, with num_trials : 165
# Found 167 / 500, with num_trials : 166
# Found 168 / 500, with num_trials : 167
# Found 169 / 500, with num_trials : 168
# Found 170 / 500, with num_trials : 169
# Found 171 / 500, with num_trials : 170
# Found 172 / 500, with num_trials : 171
# Found 173 / 500, with num_trials : 172
# Found 174 / 500, with num_trials : 173
# Found 175 / 500, with num_trials : 174
# Found 176 / 500, with num_trials : 175
# Found 177 / 500, with num_trials : 176
# Found 178 / 500, with num_trials : 177
# Found 179 / 500, with num_trials : 178
# Found 180 / 500, with num_trials : 179
# Found 181 / 500, with num_trials : 180
# Found 182 / 500, with num_trials : 181
# Found 183 / 500, with num_trials : 182
# Found 184 / 500, with num_trials : 183
# Found 185 / 500, with num_trials : 184
# Found 186 / 500, with num_trials : 185
# Found 187 / 500, with num_trials : 186
# Found 188 / 500, with num_trials : 187
# Found 189 / 500, with num_trials : 188
# Found 190 / 500, with num_trials : 189
# Found 191 / 500, with num_trials : 190
# Found 192 / 500, with num_trials : 191
# Found 193 / 500, with num_trials : 192
# Found 194 / 500, with num_trials : 193
# Found 195 / 500, with num_trials : 194
# Found 196 / 500, with num_trials : 195
# Found 197 / 500, with num_trials : 196
# Found 198 / 500, with num_trials : 197
# Found 199 / 500, with num_trials : 198
# Found 200 / 500, with num_trials : 199
# Found 201 / 500, with num_trials : 200
# Found 202 / 500, with num_trials : 201
# Found 203 / 500, with num_trials : 202
# Found 204 / 500, with num_trials : 203
# Found 205 / 500, with num_trials : 204
# Found 206 / 500, with num_trials : 205
# Found 207 / 500, with num_trials : 206
# Found 208 / 500, with num_trials : 207
# Found 209 / 500, with num_trials : 208
# Found 210 / 500, with num_trials : 209
# Found 211 / 500, with num_trials : 210
# Found 212 / 500, with num_trials : 211
# Found 213 / 500, with num_trials : 212
# Found 214 / 500, with num_trials : 213
# Found 215 / 500, with num_trials : 214
# Found 216 / 500, with num_trials : 215
# Found 217 / 500, with num_trials : 216
# Found 218 / 500, with num_trials : 217
# Found 219 / 500, with num_trials : 218
# Found 220 / 500, with num_trials : 219
# Found 221 / 500, with num_trials : 220
# Found 222 / 500, with num_trials : 221
# Found 223 / 500, with num_trials : 222
# Found 224 / 500, with num_trials : 223
# Found 225 / 500, with num_trials : 224
# Found 226 / 500, with num_trials : 225
# Found 227 / 500, with num_trials : 226
# Found 228 / 500, with num_trials : 227
# Found 229 / 500, with num_trials : 228
# Found 230 / 500, with num_trials : 229
# Found 231 / 500, with num_trials : 230
# Found 232 / 500, with num_trials : 231
# Found 233 / 500, with num_trials : 232
# Found 234 / 500, with num_trials : 233
# Found 235 / 500, with num_trials : 234
# Found 236 / 500, with num_trials : 235
# Found 237 / 500, with num_trials : 236
# Found 238 / 500, with num_trials : 237
# Found 239 / 500, with num_trials : 238
# Found 240 / 500, with num_trials : 239
# Found 241 / 500, with num_trials : 240
# Found 242 / 500, with num_trials : 241
# Found 243 / 500, with num_trials : 242
# Found 244 / 500, with num_trials : 243
# Found 245 / 500, with num_trials : 244
# Found 246 / 500, with num_trials : 245
# Found 247 / 500, with num_trials : 246
# Found 248 / 500, with num_trials : 247
# Found 249 / 500, with num_trials : 248
# Found 250 / 500, with num_trials : 249
# Found 251 / 500, with num_trials : 250
# Found 252 / 500, with num_trials : 251
# Found 253 / 500, with num_trials : 252
# Found 254 / 500, with num_trials : 253
# Found 255 / 500, with num_trials : 254
# Found 256 / 500, with num_trials : 255
# Found 257 / 500, with num_trials : 256
# Found 258 / 500, with num_trials : 257
# Found 259 / 500, with num_trials : 258
# Found 260 / 500, with num_trials : 259
# Found 261 / 500, with num_trials : 260
# Found 262 / 500, with num_trials : 261
# Found 263 / 500, with num_trials : 262
# Found 264 / 500, with num_trials : 263
# Found 265 / 500, with num_trials : 264
# Found 266 / 500, with num_trials : 265
# Found 267 / 500, with num_trials : 266
# Found 268 / 500, with num_trials : 267
# Found 269 / 500, with num_trials : 268
# Found 270 / 500, with num_trials : 269
# Found 271 / 500, with num_trials : 270
# Found 272 / 500, with num_trials : 271
# Found 273 / 500, with num_trials : 272
# Found 274 / 500, with num_trials : 273
# Found 275 / 500, with num_trials : 274
# Found 276 / 500, with num_trials : 275
# Found 277 / 500, with num_trials : 276
# Found 278 / 500, with num_trials : 277
# Found 279 / 500, with num_trials : 278
# Found 280 / 500, with num_trials : 279
# Found 281 / 500, with num_trials : 280
# Found 282 / 500, with num_trials : 281
# Found 283 / 500, with num_trials : 282
# Found 284 / 500, with num_trials : 283
# Found 285 / 500, with num_trials : 284
# Found 286 / 500, with num_trials : 285
# Found 287 / 500, with num_trials : 286
# Found 288 / 500, with num_trials : 287
# Found 289 / 500, with num_trials : 288
# Found 290 / 500, with num_trials : 289
# Found 291 / 500, with num_trials : 290
# Found 292 / 500, with num_trials : 291
# Found 293 / 500, with num_trials : 292
# Found 294 / 500, with num_trials : 293
# Found 295 / 500, with num_trials : 294
# Found 296 / 500, with num_trials : 295
# Found 297 / 500, with num_trials : 296
# Found 298 / 500, with num_trials : 297
# Found 299 / 500, with num_trials : 298
# Found 300 / 500, with num_trials : 299
# Found 301 / 500, with num_trials : 300
# Found 302 / 500, with num_trials : 301
# Found 303 / 500, with num_trials : 302
# Found 304 / 500, with num_trials : 303
# Found 305 / 500, with num_trials : 304
# Found 306 / 500, with num_trials : 305
# Found 307 / 500, with num_trials : 306
# Found 308 / 500, with num_trials : 307
# Found 309 / 500, with num_trials : 308
# Found 310 / 500, with num_trials : 309
# Found 311 / 500, with num_trials : 310
# Found 312 / 500, with num_trials : 311
# Found 313 / 500, with num_trials : 312
# Found 314 / 500, with num_trials : 313
# Found 315 / 500, with num_trials : 314
# Found 316 / 500, with num_trials : 315
# Found 317 / 500, with num_trials : 316
# Found 318 / 500, with num_trials : 317
# Found 319 / 500, with num_trials : 318
# Found 320 / 500, with num_trials : 319
# Found 321 / 500, with num_trials : 320
# Found 322 / 500, with num_trials : 321
# Found 323 / 500, with num_trials : 322
# Found 324 / 500, with num_trials : 323
# Found 325 / 500, with num_trials : 324
# Found 326 / 500, with num_trials : 325
# Found 327 / 500, with num_trials : 326
# Found 328 / 500, with num_trials : 327
# Found 329 / 500, with num_trials : 328
# Found 330 / 500, with num_trials : 329
# Found 331 / 500, with num_trials : 330
# Found 332 / 500, with num_trials : 331
# Found 333 / 500, with num_trials : 332
# Found 334 / 500, with num_trials : 333
# Found 335 / 500, with num_trials : 334
# Found 336 / 500, with num_trials : 335
# Found 337 / 500, with num_trials : 336
# Found 338 / 500, with num_trials : 337
# Found 339 / 500, with num_trials : 338
# Found 340 / 500, with num_trials : 339
# Found 341 / 500, with num_trials : 340
# Found 342 / 500, with num_trials : 341
# Found 343 / 500, with num_trials : 342
# Found 344 / 500, with num_trials : 343
# Found 345 / 500, with num_trials : 344
# Found 346 / 500, with num_trials : 345
# Found 347 / 500, with num_trials : 346
# Found 348 / 500, with num_trials : 347
# Found 349 / 500, with num_trials : 348
# Found 350 / 500, with num_trials : 349
# Found 351 / 500, with num_trials : 350
# Found 352 / 500, with num_trials : 351
# Found 353 / 500, with num_trials : 352
# Found 354 / 500, with num_trials : 353
# Found 355 / 500, with num_trials : 354
# Found 356 / 500, with num_trials : 355
# Found 357 / 500, with num_trials : 356
# Found 358 / 500, with num_trials : 357
# Found 359 / 500, with num_trials : 359
# Found 360 / 500, with num_trials : 360
# Found 361 / 500, with num_trials : 361
# Found 362 / 500, with num_trials : 362
# Found 363 / 500, with num_trials : 363
# Found 364 / 500, with num_trials : 364
# Found 365 / 500, with num_trials : 365
# Found 366 / 500, with num_trials : 366
# Found 367 / 500, with num_trials : 367
# Found 368 / 500, with num_trials : 368
# Found 369 / 500, with num_trials : 369
# Found 370 / 500, with num_trials : 370
# Found 371 / 500, with num_trials : 371
# Found 372 / 500, with num_trials : 372
# Found 373 / 500, with num_trials : 373
# Found 374 / 500, with num_trials : 374
# Found 375 / 500, with num_trials : 375
# Found 376 / 500, with num_trials : 376
# Found 377 / 500, with num_trials : 377
# Found 378 / 500, with num_trials : 378
# Found 379 / 500, with num_trials : 379
# Found 380 / 500, with num_trials : 380
# Found 381 / 500, with num_trials : 381
# Found 382 / 500, with num_trials : 382
# Found 383 / 500, with num_trials : 383
# Found 384 / 500, with num_trials : 384
# Found 385 / 500, with num_trials : 385
# Found 386 / 500, with num_trials : 386
# Found 387 / 500, with num_trials : 387
# Found 388 / 500, with num_trials : 388
# Found 389 / 500, with num_trials : 389
# Found 390 / 500, with num_trials : 390
# Found 391 / 500, with num_trials : 391
# Found 392 / 500, with num_trials : 392
# Found 393 / 500, with num_trials : 393
# Found 394 / 500, with num_trials : 394
# Found 395 / 500, with num_trials : 395
# Found 396 / 500, with num_trials : 396
# Found 397 / 500, with num_trials : 397
# Found 398 / 500, with num_trials : 398
# Found 399 / 500, with num_trials : 399
# Found 400 / 500, with num_trials : 400
# Found 401 / 500, with num_trials : 401
# Found 402 / 500, with num_trials : 402
# Found 403 / 500, with num_trials : 403
# Found 404 / 500, with num_trials : 404
# Found 405 / 500, with num_trials : 405
# Found 406 / 500, with num_trials : 406
# Found 407 / 500, with num_trials : 407
# Found 408 / 500, with num_trials : 408
# Found 409 / 500, with num_trials : 409
# Found 410 / 500, with num_trials : 410
# Found 411 / 500, with num_trials : 411
# Found 412 / 500, with num_trials : 412
# Found 413 / 500, with num_trials : 413
# Found 414 / 500, with num_trials : 414
# Found 415 / 500, with num_trials : 415
# Found 416 / 500, with num_trials : 416
# Found 417 / 500, with num_trials : 417
# Found 418 / 500, with num_trials : 418
# Found 419 / 500, with num_trials : 419
# Found 420 / 500, with num_trials : 420
# Found 421 / 500, with num_trials : 421
# Found 422 / 500, with num_trials : 422
# Found 423 / 500, with num_trials : 423
# Found 424 / 500, with num_trials : 424
# Found 425 / 500, with num_trials : 425
# Found 426 / 500, with num_trials : 426
# Found 427 / 500, with num_trials : 427
# Found 428 / 500, with num_trials : 428
# Found 429 / 500, with num_trials : 429
# Found 430 / 500, with num_trials : 430
# Found 431 / 500, with num_trials : 431
# Found 432 / 500, with num_trials : 432
# Found 433 / 500, with num_trials : 433
# Found 434 / 500, with num_trials : 434
# Found 435 / 500, with num_trials : 435
# Found 436 / 500, with num_trials : 436
# Found 437 / 500, with num_trials : 437
# Found 438 / 500, with num_trials : 438
# Found 439 / 500, with num_trials : 439
# Found 440 / 500, with num_trials : 440
# Found 441 / 500, with num_trials : 441
# Found 442 / 500, with num_trials : 442
# Found 443 / 500, with num_trials : 443
# Found 444 / 500, with num_trials : 444
# Found 445 / 500, with num_trials : 445
# Found 446 / 500, with num_trials : 446
# Found 447 / 500, with num_trials : 447
# Found 448 / 500, with num_trials : 448
# Found 449 / 500, with num_trials : 449
# Found 450 / 500, with num_trials : 450
# Found 451 / 500, with num_trials : 451
# Found 452 / 500, with num_trials : 452
# Found 453 / 500, with num_trials : 453
# Found 454 / 500, with num_trials : 454
# Found 455 / 500, with num_trials : 455
# Found 456 / 500, with num_trials : 456
# Found 457 / 500, with num_trials : 458
# Found 458 / 500, with num_trials : 459
# Found 459 / 500, with num_trials : 460
# Found 460 / 500, with num_trials : 461
# Found 461 / 500, with num_trials : 462
# Found 462 / 500, with num_trials : 463
# Found 463 / 500, with num_trials : 464
# Found 464 / 500, with num_trials : 465
# Found 465 / 500, with num_trials : 466
# Found 466 / 500, with num_trials : 467
# Found 467 / 500, with num_trials : 468
# Found 468 / 500, with num_trials : 469
# Found 469 / 500, with num_trials : 470
# Found 470 / 500, with num_trials : 471
# Found 471 / 500, with num_trials : 472
# Found 472 / 500, with num_trials : 473
# Found 473 / 500, with num_trials : 474
# Found 474 / 500, with num_trials : 475
# Found 475 / 500, with num_trials : 476
# Found 476 / 500, with num_trials : 477
# Found 477 / 500, with num_trials : 478
# Found 478 / 500, with num_trials : 479
# Found 479 / 500, with num_trials : 480
# Found 480 / 500, with num_trials : 481
# Found 481 / 500, with num_trials : 482
# Found 482 / 500, with num_trials : 483
# Found 483 / 500, with num_trials : 484
# Found 484 / 500, with num_trials : 485
# Found 485 / 500, with num_trials : 486
# Found 486 / 500, with num_trials : 487
# Found 487 / 500, with num_trials : 488
# Found 488 / 500, with num_trials : 489
# Found 489 / 500, with num_trials : 490
# Found 490 / 500, with num_trials : 491
# Found 491 / 500, with num_trials : 492
# Found 492 / 500, with num_trials : 493
# Found 493 / 500, with num_trials : 494
# Found 494 / 500, with num_trials : 495
# Found 495 / 500, with num_trials : 496
# Found 496 / 500, with num_trials : 497
# Found 497 / 500, with num_trials : 498
# Found 498 / 500, with num_trials : 499
# Found 499 / 500, with num_trials : 500
# Found 500 / 500, with num_trials : 501
# Finished p=0.19952623149688797 with num_trials=502
# ------------------------------------------------------------------
# Found 1 / 500, with num_trials : 0
# Found 2 / 500, with num_trials : 1
# Found 3 / 500, with num_trials : 2
# Found 4 / 500, with num_trials : 3
# Found 5 / 500, with num_trials : 4
# Found 6 / 500, with num_trials : 5
# Found 7 / 500, with num_trials : 6
# Found 8 / 500, with num_trials : 7
# Found 9 / 500, with num_trials : 8
# Found 10 / 500, with num_trials : 9
# Found 11 / 500, with num_trials : 10
# Found 12 / 500, with num_trials : 11
# Found 13 / 500, with num_trials : 12
# Found 14 / 500, with num_trials : 13
# Found 15 / 500, with num_trials : 14
# Found 16 / 500, with num_trials : 15
# Found 17 / 500, with num_trials : 16
# Found 18 / 500, with num_trials : 17
# Found 19 / 500, with num_trials : 18
# Found 20 / 500, with num_trials : 19
# Found 21 / 500, with num_trials : 20
# Found 22 / 500, with num_trials : 21
# Found 23 / 500, with num_trials : 22
# Found 24 / 500, with num_trials : 23
# Found 25 / 500, with num_trials : 24
# Found 26 / 500, with num_trials : 25
# Found 27 / 500, with num_trials : 26
# Found 28 / 500, with num_trials : 27
# Found 29 / 500, with num_trials : 28
# Found 30 / 500, with num_trials : 29
# Found 31 / 500, with num_trials : 30
# Found 32 / 500, with num_trials : 31
# Found 33 / 500, with num_trials : 32
# Found 34 / 500, with num_trials : 33
# Found 35 / 500, with num_trials : 34
# Found 36 / 500, with num_trials : 35
# Found 37 / 500, with num_trials : 36
# Found 38 / 500, with num_trials : 37
# Found 39 / 500, with num_trials : 38
# Found 40 / 500, with num_trials : 39
# Found 41 / 500, with num_trials : 40
# Found 42 / 500, with num_trials : 41
# Found 43 / 500, with num_trials : 42
# Found 44 / 500, with num_trials : 43
# Found 45 / 500, with num_trials : 44
# Found 46 / 500, with num_trials : 45
# Found 47 / 500, with num_trials : 46
# Found 48 / 500, with num_trials : 47
# Found 49 / 500, with num_trials : 48
# Found 50 / 500, with num_trials : 49
# Found 51 / 500, with num_trials : 50
# Found 52 / 500, with num_trials : 51
# Found 53 / 500, with num_trials : 52
# Found 54 / 500, with num_trials : 53
# Found 55 / 500, with num_trials : 54
# Found 56 / 500, with num_trials : 55
# Found 57 / 500, with num_trials : 57
# Found 58 / 500, with num_trials : 58
# Found 59 / 500, with num_trials : 59
# Found 60 / 500, with num_trials : 60
# Found 61 / 500, with num_trials : 61
# Found 62 / 500, with num_trials : 62
# Found 63 / 500, with num_trials : 63
# Found 64 / 500, with num_trials : 64
# Found 65 / 500, with num_trials : 65
# Found 66 / 500, with num_trials : 66
# Found 67 / 500, with num_trials : 67
# Found 68 / 500, with num_trials : 68
# Found 69 / 500, with num_trials : 69
# Found 70 / 500, with num_trials : 70
# Found 71 / 500, with num_trials : 72
# Found 72 / 500, with num_trials : 73
# Found 73 / 500, with num_trials : 74
# Found 74 / 500, with num_trials : 75
# Found 75 / 500, with num_trials : 76
# Found 76 / 500, with num_trials : 77
# Found 77 / 500, with num_trials : 78
# Found 78 / 500, with num_trials : 79
# Found 79 / 500, with num_trials : 80
# Found 80 / 500, with num_trials : 81
# Found 81 / 500, with num_trials : 82
# Found 82 / 500, with num_trials : 83
# Found 83 / 500, with num_trials : 84
# Found 84 / 500, with num_trials : 85
# Found 85 / 500, with num_trials : 86
# Found 86 / 500, with num_trials : 87
# Found 87 / 500, with num_trials : 88
# Found 88 / 500, with num_trials : 89
# Found 89 / 500, with num_trials : 90
# Found 90 / 500, with num_trials : 91
# Found 91 / 500, with num_trials : 92
# Found 92 / 500, with num_trials : 93
# Found 93 / 500, with num_trials : 94
# Found 94 / 500, with num_trials : 95
# Found 95 / 500, with num_trials : 96
# Found 96 / 500, with num_trials : 98
# Found 97 / 500, with num_trials : 99
# UPDATE: Found 97 / 500, with num_trials : 100
# Found 98 / 500, with num_trials : 102
# Found 99 / 500, with num_trials : 103
# Found 100 / 500, with num_trials : 104
# Found 101 / 500, with num_trials : 105
# Found 102 / 500, with num_trials : 106
# Found 103 / 500, with num_trials : 108
# Found 104 / 500, with num_trials : 109
# Found 105 / 500, with num_trials : 110
# Found 106 / 500, with num_trials : 111
# Found 107 / 500, with num_trials : 113
# Found 108 / 500, with num_trials : 114
# Found 109 / 500, with num_trials : 115
# Found 110 / 500, with num_trials : 116
# Found 111 / 500, with num_trials : 117
# Found 112 / 500, with num_trials : 118
# Found 113 / 500, with num_trials : 119
# Found 114 / 500, with num_trials : 120
# Found 115 / 500, with num_trials : 121
# Found 116 / 500, with num_trials : 122
# Found 117 / 500, with num_trials : 123
# Found 118 / 500, with num_trials : 124
# Found 119 / 500, with num_trials : 125
# Found 120 / 500, with num_trials : 126
# Found 121 / 500, with num_trials : 127
# Found 122 / 500, with num_trials : 128
# Found 123 / 500, with num_trials : 129
# Found 124 / 500, with num_trials : 130
# Found 125 / 500, with num_trials : 131
# Found 126 / 500, with num_trials : 132
# Found 127 / 500, with num_trials : 133
# Found 128 / 500, with num_trials : 134
# Found 129 / 500, with num_trials : 135
# Found 130 / 500, with num_trials : 136
# Found 131 / 500, with num_trials : 137
# Found 132 / 500, with num_trials : 138
# Found 133 / 500, with num_trials : 140
# Found 134 / 500, with num_trials : 141
# Found 135 / 500, with num_trials : 142
# Found 136 / 500, with num_trials : 143
# Found 137 / 500, with num_trials : 144
# Found 138 / 500, with num_trials : 145
# Found 139 / 500, with num_trials : 146
# Found 140 / 500, with num_trials : 147
# Found 141 / 500, with num_trials : 148
# Found 142 / 500, with num_trials : 149
# Found 143 / 500, with num_trials : 150
# Found 144 / 500, with num_trials : 151
# Found 145 / 500, with num_trials : 152
# Found 146 / 500, with num_trials : 153
# Found 147 / 500, with num_trials : 154
# Found 148 / 500, with num_trials : 155
# Found 149 / 500, with num_trials : 156
# Found 150 / 500, with num_trials : 157
# Found 151 / 500, with num_trials : 158
# Found 152 / 500, with num_trials : 159
# Found 153 / 500, with num_trials : 160
# Found 154 / 500, with num_trials : 161
# Found 155 / 500, with num_trials : 162
# Found 156 / 500, with num_trials : 163
# Found 157 / 500, with num_trials : 164
# Found 158 / 500, with num_trials : 167
# Found 159 / 500, with num_trials : 169
# Found 160 / 500, with num_trials : 170
# Found 161 / 500, with num_trials : 171
# Found 162 / 500, with num_trials : 172
# Found 163 / 500, with num_trials : 174
# Found 164 / 500, with num_trials : 176
# Found 165 / 500, with num_trials : 177
# Found 166 / 500, with num_trials : 178
# Found 167 / 500, with num_trials : 179
# Found 168 / 500, with num_trials : 180
# Found 169 / 500, with num_trials : 181
# Found 170 / 500, with num_trials : 182
# Found 171 / 500, with num_trials : 183
# Found 172 / 500, with num_trials : 184
# Found 173 / 500, with num_trials : 185
# Found 174 / 500, with num_trials : 186
# Found 175 / 500, with num_trials : 187
# Found 176 / 500, with num_trials : 188
# Found 177 / 500, with num_trials : 189
# Found 178 / 500, with num_trials : 190
# Found 179 / 500, with num_trials : 191
# Found 180 / 500, with num_trials : 192
# Found 181 / 500, with num_trials : 193
# Found 182 / 500, with num_trials : 194
# Found 183 / 500, with num_trials : 195
# Found 184 / 500, with num_trials : 196
# Found 185 / 500, with num_trials : 197
# Found 186 / 500, with num_trials : 198
# Found 187 / 500, with num_trials : 199
# Found 188 / 500, with num_trials : 200
# Found 189 / 500, with num_trials : 201
# Found 190 / 500, with num_trials : 202
# Found 191 / 500, with num_trials : 203
# Found 192 / 500, with num_trials : 204
# Found 193 / 500, with num_trials : 205
# Found 194 / 500, with num_trials : 206
# Found 195 / 500, with num_trials : 207
# Found 196 / 500, with num_trials : 208
# Found 197 / 500, with num_trials : 209
# Found 198 / 500, with num_trials : 210
# Found 199 / 500, with num_trials : 211
# Found 200 / 500, with num_trials : 213
# Found 201 / 500, with num_trials : 214
# Found 202 / 500, with num_trials : 215
# Found 203 / 500, with num_trials : 216
# Found 204 / 500, with num_trials : 217
# Found 205 / 500, with num_trials : 218
# Found 206 / 500, with num_trials : 219
# Found 207 / 500, with num_trials : 220
# Found 208 / 500, with num_trials : 221
# Found 209 / 500, with num_trials : 222
# Found 210 / 500, with num_trials : 223
# Found 211 / 500, with num_trials : 224
# Found 212 / 500, with num_trials : 225
# Found 213 / 500, with num_trials : 226
# Found 214 / 500, with num_trials : 227
# Found 215 / 500, with num_trials : 228
# Found 216 / 500, with num_trials : 229
# Found 217 / 500, with num_trials : 230
# Found 218 / 500, with num_trials : 231
# Found 219 / 500, with num_trials : 232
# Found 220 / 500, with num_trials : 233
# Found 221 / 500, with num_trials : 234
# Found 222 / 500, with num_trials : 235
# Found 223 / 500, with num_trials : 236
# Found 224 / 500, with num_trials : 237
# Found 225 / 500, with num_trials : 238
# Found 226 / 500, with num_trials : 239
# Found 227 / 500, with num_trials : 240
# Found 228 / 500, with num_trials : 241
# Found 229 / 500, with num_trials : 242
# Found 230 / 500, with num_trials : 243
# Found 231 / 500, with num_trials : 244
# Found 232 / 500, with num_trials : 245
# Found 233 / 500, with num_trials : 246
# Found 234 / 500, with num_trials : 247
# Found 235 / 500, with num_trials : 249
# Found 236 / 500, with num_trials : 250
# Found 237 / 500, with num_trials : 252
# Found 238 / 500, with num_trials : 253
# Found 239 / 500, with num_trials : 254
# Found 240 / 500, with num_trials : 255
# Found 241 / 500, with num_trials : 256
# Found 242 / 500, with num_trials : 257
# Found 243 / 500, with num_trials : 258
# Found 244 / 500, with num_trials : 259
# Found 245 / 500, with num_trials : 260
# Found 246 / 500, with num_trials : 261
# Found 247 / 500, with num_trials : 262
# Found 248 / 500, with num_trials : 264
# Found 249 / 500, with num_trials : 265
# Found 250 / 500, with num_trials : 266
# Found 251 / 500, with num_trials : 267
# Found 252 / 500, with num_trials : 268
# Found 253 / 500, with num_trials : 269
# Found 254 / 500, with num_trials : 270
# Found 255 / 500, with num_trials : 271
# Found 256 / 500, with num_trials : 272
# Found 257 / 500, with num_trials : 273
# Found 258 / 500, with num_trials : 274
# Found 259 / 500, with num_trials : 275
# Found 260 / 500, with num_trials : 276
# Found 261 / 500, with num_trials : 277
# Found 262 / 500, with num_trials : 278
# Found 263 / 500, with num_trials : 279
# Found 264 / 500, with num_trials : 280
# Found 265 / 500, with num_trials : 281
# Found 266 / 500, with num_trials : 282
# Found 267 / 500, with num_trials : 283
# Found 268 / 500, with num_trials : 284
# Found 269 / 500, with num_trials : 285
# Found 270 / 500, with num_trials : 286
# Found 271 / 500, with num_trials : 287
# Found 272 / 500, with num_trials : 288
# Found 273 / 500, with num_trials : 289
# Found 274 / 500, with num_trials : 290
# Found 275 / 500, with num_trials : 291
# Found 276 / 500, with num_trials : 292
# Found 277 / 500, with num_trials : 293
# Found 278 / 500, with num_trials : 294
# Found 279 / 500, with num_trials : 295
# Found 280 / 500, with num_trials : 296
# Found 281 / 500, with num_trials : 297
# Found 282 / 500, with num_trials : 298
# Found 283 / 500, with num_trials : 299
# Found 284 / 500, with num_trials : 300
# Found 285 / 500, with num_trials : 302
# Found 286 / 500, with num_trials : 303
# Found 287 / 500, with num_trials : 304
# Found 288 / 500, with num_trials : 305
# Found 289 / 500, with num_trials : 306
# Found 290 / 500, with num_trials : 307
# Found 291 / 500, with num_trials : 308
# Found 292 / 500, with num_trials : 309
# Found 293 / 500, with num_trials : 310
# Found 294 / 500, with num_trials : 311
# Found 295 / 500, with num_trials : 312
# Found 296 / 500, with num_trials : 314
# Found 297 / 500, with num_trials : 315
# Found 298 / 500, with num_trials : 316
# Found 299 / 500, with num_trials : 317
# Found 300 / 500, with num_trials : 318
# Found 301 / 500, with num_trials : 320
# Found 302 / 500, with num_trials : 321
# Found 303 / 500, with num_trials : 323
# Found 304 / 500, with num_trials : 324
# Found 305 / 500, with num_trials : 325
# Found 306 / 500, with num_trials : 326
# Found 307 / 500, with num_trials : 327
# Found 308 / 500, with num_trials : 328
# Found 309 / 500, with num_trials : 329
# Found 310 / 500, with num_trials : 330
# Found 311 / 500, with num_trials : 332
# Found 312 / 500, with num_trials : 333
# Found 313 / 500, with num_trials : 334
# Found 314 / 500, with num_trials : 335
# Found 315 / 500, with num_trials : 336
# Found 316 / 500, with num_trials : 337
# Found 317 / 500, with num_trials : 338
# Found 318 / 500, with num_trials : 339
# Found 319 / 500, with num_trials : 340
# Found 320 / 500, with num_trials : 341
# Found 321 / 500, with num_trials : 342
# Found 322 / 500, with num_trials : 343
# Found 323 / 500, with num_trials : 344
# Found 324 / 500, with num_trials : 345
# Found 325 / 500, with num_trials : 346
# Found 326 / 500, with num_trials : 347
# Found 327 / 500, with num_trials : 348
# Found 328 / 500, with num_trials : 349
# Found 329 / 500, with num_trials : 350
# Found 330 / 500, with num_trials : 351
# Found 331 / 500, with num_trials : 352
# Found 332 / 500, with num_trials : 353
# Found 333 / 500, with num_trials : 354
# Found 334 / 500, with num_trials : 355
# Found 335 / 500, with num_trials : 356
# Found 336 / 500, with num_trials : 357
# Found 337 / 500, with num_trials : 358
# Found 338 / 500, with num_trials : 359
# Found 339 / 500, with num_trials : 361
# Found 340 / 500, with num_trials : 362
# Found 341 / 500, with num_trials : 363
# Found 342 / 500, with num_trials : 364
# Found 343 / 500, with num_trials : 366
# Found 344 / 500, with num_trials : 367
# Found 345 / 500, with num_trials : 368
# Found 346 / 500, with num_trials : 369
# Found 347 / 500, with num_trials : 370
# Found 348 / 500, with num_trials : 371
# Found 349 / 500, with num_trials : 372
# Found 350 / 500, with num_trials : 373
# Found 351 / 500, with num_trials : 374
# Found 352 / 500, with num_trials : 375
# Found 353 / 500, with num_trials : 376
# Found 354 / 500, with num_trials : 378
# Found 355 / 500, with num_trials : 379
# Found 356 / 500, with num_trials : 380
# Found 357 / 500, with num_trials : 381
# Found 358 / 500, with num_trials : 382
# Found 359 / 500, with num_trials : 383
# Found 360 / 500, with num_trials : 384
# Found 361 / 500, with num_trials : 385
# Found 362 / 500, with num_trials : 387
# Found 363 / 500, with num_trials : 388
# Found 364 / 500, with num_trials : 389
# Found 365 / 500, with num_trials : 391
# Found 366 / 500, with num_trials : 392
# Found 367 / 500, with num_trials : 393
# Found 368 / 500, with num_trials : 394
# Found 369 / 500, with num_trials : 396
# Found 370 / 500, with num_trials : 397
# Found 371 / 500, with num_trials : 398
# Found 372 / 500, with num_trials : 399
# Found 373 / 500, with num_trials : 400
# Found 374 / 500, with num_trials : 401
# Found 375 / 500, with num_trials : 402
# Found 376 / 500, with num_trials : 403
# Found 377 / 500, with num_trials : 404
# Found 378 / 500, with num_trials : 405
# Found 379 / 500, with num_trials : 406
# Found 380 / 500, with num_trials : 407
# Found 381 / 500, with num_trials : 408
# Found 382 / 500, with num_trials : 410
# Found 383 / 500, with num_trials : 411
# Found 384 / 500, with num_trials : 412
# Found 385 / 500, with num_trials : 413
# Found 386 / 500, with num_trials : 415
# Found 387 / 500, with num_trials : 416
# Found 388 / 500, with num_trials : 417
# Found 389 / 500, with num_trials : 418
# Found 390 / 500, with num_trials : 419
# Found 391 / 500, with num_trials : 420
# Found 392 / 500, with num_trials : 421
# Found 393 / 500, with num_trials : 422
# Found 394 / 500, with num_trials : 423
# Found 395 / 500, with num_trials : 424
# Found 396 / 500, with num_trials : 425
# Found 397 / 500, with num_trials : 426
# Found 398 / 500, with num_trials : 427
# Found 399 / 500, with num_trials : 428
# Found 400 / 500, with num_trials : 429
# Found 401 / 500, with num_trials : 430
# Found 402 / 500, with num_trials : 431
# Found 403 / 500, with num_trials : 432
# Found 404 / 500, with num_trials : 433
# Found 405 / 500, with num_trials : 435
# Found 406 / 500, with num_trials : 436
# Found 407 / 500, with num_trials : 437
# Found 408 / 500, with num_trials : 438
# Found 409 / 500, with num_trials : 439
# Found 410 / 500, with num_trials : 440
# Found 411 / 500, with num_trials : 441
# Found 412 / 500, with num_trials : 442
# Found 413 / 500, with num_trials : 443
# Found 414 / 500, with num_trials : 444
# Found 415 / 500, with num_trials : 445
# Found 416 / 500, with num_trials : 446
# Found 417 / 500, with num_trials : 447
# Found 418 / 500, with num_trials : 448
# Found 419 / 500, with num_trials : 449
# Found 420 / 500, with num_trials : 450
# Found 421 / 500, with num_trials : 452
# Found 422 / 500, with num_trials : 453
# Found 423 / 500, with num_trials : 454
# Found 424 / 500, with num_trials : 455
# Found 425 / 500, with num_trials : 456
# Found 426 / 500, with num_trials : 457
# Found 427 / 500, with num_trials : 458
# Found 428 / 500, with num_trials : 459
# Found 429 / 500, with num_trials : 461
# Found 430 / 500, with num_trials : 462
# Found 431 / 500, with num_trials : 463
# Found 432 / 500, with num_trials : 464
# Found 433 / 500, with num_trials : 466
# Found 434 / 500, with num_trials : 467
# Found 435 / 500, with num_trials : 468
# Found 436 / 500, with num_trials : 469
# Found 437 / 500, with num_trials : 470
# Found 438 / 500, with num_trials : 471
# Found 439 / 500, with num_trials : 472
# Found 440 / 500, with num_trials : 473
# Found 441 / 500, with num_trials : 474
# Found 442 / 500, with num_trials : 475
# Found 443 / 500, with num_trials : 476
# Found 444 / 500, with num_trials : 477
# Found 445 / 500, with num_trials : 478
# Found 446 / 500, with num_trials : 479
# Found 447 / 500, with num_trials : 480
# Found 448 / 500, with num_trials : 481
# Found 449 / 500, with num_trials : 482
# Found 450 / 500, with num_trials : 483
# Found 451 / 500, with num_trials : 484
# Found 452 / 500, with num_trials : 485
# Found 453 / 500, with num_trials : 486
# Found 454 / 500, with num_trials : 487
# Found 455 / 500, with num_trials : 488
# Found 456 / 500, with num_trials : 489
# Found 457 / 500, with num_trials : 490
# Found 458 / 500, with num_trials : 491
# Found 459 / 500, with num_trials : 492
# Found 460 / 500, with num_trials : 494
# Found 461 / 500, with num_trials : 495
# Found 462 / 500, with num_trials : 496
# Found 463 / 500, with num_trials : 497
# Found 464 / 500, with num_trials : 498
# Found 465 / 500, with num_trials : 499
# Found 466 / 500, with num_trials : 500
# Found 467 / 500, with num_trials : 501
# Found 468 / 500, with num_trials : 502
# Found 469 / 500, with num_trials : 503
# Found 470 / 500, with num_trials : 504
# Found 471 / 500, with num_trials : 506
# Found 472 / 500, with num_trials : 507
# Found 473 / 500, with num_trials : 508
# Found 474 / 500, with num_trials : 509
# Found 475 / 500, with num_trials : 510
# Found 476 / 500, with num_trials : 511
# Found 477 / 500, with num_trials : 512
# Found 478 / 500, with num_trials : 513
# Found 479 / 500, with num_trials : 514
# Found 480 / 500, with num_trials : 515
# Found 481 / 500, with num_trials : 516
# Found 482 / 500, with num_trials : 517
# Found 483 / 500, with num_trials : 518
# Found 484 / 500, with num_trials : 519
# Found 485 / 500, with num_trials : 520
# Found 486 / 500, with num_trials : 521
# Found 487 / 500, with num_trials : 522
# Found 488 / 500, with num_trials : 523
# Found 489 / 500, with num_trials : 524
# Found 490 / 500, with num_trials : 525
# Found 491 / 500, with num_trials : 526
# Found 492 / 500, with num_trials : 527
# Found 493 / 500, with num_trials : 528
# Found 494 / 500, with num_trials : 529
# Found 495 / 500, with num_trials : 530
# Found 496 / 500, with num_trials : 531
# Found 497 / 500, with num_trials : 532
# Found 498 / 500, with num_trials : 533
# Found 499 / 500, with num_trials : 534
# Found 500 / 500, with num_trials : 535
# Finished p=0.15448591479026755 with num_trials=536
# ------------------------------------------------------------------
# Found 1 / 500, with num_trials : 0
# Found 2 / 500, with num_trials : 2
# Found 3 / 500, with num_trials : 3
# Found 4 / 500, with num_trials : 4
# Found 5 / 500, with num_trials : 6
# Found 6 / 500, with num_trials : 7
# Found 7 / 500, with num_trials : 8
# Found 8 / 500, with num_trials : 9
# Found 9 / 500, with num_trials : 10
# Found 10 / 500, with num_trials : 11
# Found 11 / 500, with num_trials : 12
# Found 12 / 500, with num_trials : 13
# Found 13 / 500, with num_trials : 14
# Found 14 / 500, with num_trials : 15
# Found 15 / 500, with num_trials : 18
# Found 16 / 500, with num_trials : 19
# Found 17 / 500, with num_trials : 20
# Found 18 / 500, with num_trials : 21
# Found 19 / 500, with num_trials : 22
# Found 20 / 500, with num_trials : 23
# Found 21 / 500, with num_trials : 24
# Found 22 / 500, with num_trials : 25
# Found 23 / 500, with num_trials : 26
# Found 24 / 500, with num_trials : 27
# Found 25 / 500, with num_trials : 28
# Found 26 / 500, with num_trials : 29
# Found 27 / 500, with num_trials : 30
# Found 28 / 500, with num_trials : 31
# Found 29 / 500, with num_trials : 32
# Found 30 / 500, with num_trials : 33
# Found 31 / 500, with num_trials : 34
# Found 32 / 500, with num_trials : 35
# Found 33 / 500, with num_trials : 36
# Found 34 / 500, with num_trials : 37
# Found 35 / 500, with num_trials : 38
# Found 36 / 500, with num_trials : 39
# Found 37 / 500, with num_trials : 40
# Found 38 / 500, with num_trials : 41
# Found 39 / 500, with num_trials : 43
# Found 40 / 500, with num_trials : 45
# Found 41 / 500, with num_trials : 46
# Found 42 / 500, with num_trials : 49
# Found 43 / 500, with num_trials : 50
# Found 44 / 500, with num_trials : 51
# Found 45 / 500, with num_trials : 52
# Found 46 / 500, with num_trials : 54
# Found 47 / 500, with num_trials : 55
# Found 48 / 500, with num_trials : 58
# Found 49 / 500, with num_trials : 59
# Found 50 / 500, with num_trials : 60
# Found 51 / 500, with num_trials : 61
# Found 52 / 500, with num_trials : 62
# Found 53 / 500, with num_trials : 63
# Found 54 / 500, with num_trials : 64
# Found 55 / 500, with num_trials : 65
# Found 56 / 500, with num_trials : 66
# Found 57 / 500, with num_trials : 67
# Found 58 / 500, with num_trials : 68
# Found 59 / 500, with num_trials : 69
# Found 60 / 500, with num_trials : 70
# Found 61 / 500, with num_trials : 71
# Found 62 / 500, with num_trials : 72
# Found 63 / 500, with num_trials : 73
# Found 64 / 500, with num_trials : 75
# Found 65 / 500, with num_trials : 76
# Found 66 / 500, with num_trials : 77
# Found 67 / 500, with num_trials : 78
# Found 68 / 500, with num_trials : 79
# Found 69 / 500, with num_trials : 80
# Found 70 / 500, with num_trials : 81
# Found 71 / 500, with num_trials : 82
# Found 72 / 500, with num_trials : 83
# Found 73 / 500, with num_trials : 84
# Found 74 / 500, with num_trials : 85
# Found 75 / 500, with num_trials : 86
# Found 76 / 500, with num_trials : 87
# Found 77 / 500, with num_trials : 88
# Found 78 / 500, with num_trials : 90
# Found 79 / 500, with num_trials : 91
# Found 80 / 500, with num_trials : 92
# Found 81 / 500, with num_trials : 94
# Found 82 / 500, with num_trials : 95
# Found 83 / 500, with num_trials : 96
# Found 84 / 500, with num_trials : 97
# Found 85 / 500, with num_trials : 98
# Found 86 / 500, with num_trials : 99
# Found 87 / 500, with num_trials : 100
# Found 88 / 500, with num_trials : 101
# Found 89 / 500, with num_trials : 102
# Found 90 / 500, with num_trials : 103
# Found 91 / 500, with num_trials : 105
# Found 92 / 500, with num_trials : 106
# Found 93 / 500, with num_trials : 107
# Found 94 / 500, with num_trials : 108
# Found 95 / 500, with num_trials : 109
# Found 96 / 500, with num_trials : 110
# Found 97 / 500, with num_trials : 111
# Found 98 / 500, with num_trials : 112
# Found 99 / 500, with num_trials : 113
# Found 100 / 500, with num_trials : 114
# Found 101 / 500, with num_trials : 116
# Found 102 / 500, with num_trials : 117
# Found 103 / 500, with num_trials : 119
# Found 104 / 500, with num_trials : 120
# Found 105 / 500, with num_trials : 121
# Found 106 / 500, with num_trials : 122
# Found 107 / 500, with num_trials : 123
# Found 108 / 500, with num_trials : 124
# Found 109 / 500, with num_trials : 125
# Found 110 / 500, with num_trials : 126
# Found 111 / 500, with num_trials : 128
# Found 112 / 500, with num_trials : 129
# Found 113 / 500, with num_trials : 130
# Found 114 / 500, with num_trials : 131
# Found 115 / 500, with num_trials : 132
# Found 116 / 500, with num_trials : 133
# Found 117 / 500, with num_trials : 134
# Found 118 / 500, with num_trials : 135
# Found 119 / 500, with num_trials : 136
# Found 120 / 500, with num_trials : 138
# Found 121 / 500, with num_trials : 139
# Found 122 / 500, with num_trials : 140
# Found 123 / 500, with num_trials : 141
# Found 124 / 500, with num_trials : 142
# Found 125 / 500, with num_trials : 143
# Found 126 / 500, with num_trials : 144
# Found 127 / 500, with num_trials : 145
# Found 128 / 500, with num_trials : 146
# Found 129 / 500, with num_trials : 147
# Found 130 / 500, with num_trials : 148
# Found 131 / 500, with num_trials : 149
# Found 132 / 500, with num_trials : 150
# Found 133 / 500, with num_trials : 151
# Found 134 / 500, with num_trials : 152
# Found 135 / 500, with num_trials : 153
# Found 136 / 500, with num_trials : 154
# Found 137 / 500, with num_trials : 156
# Found 138 / 500, with num_trials : 157
# Found 139 / 500, with num_trials : 158
# Found 140 / 500, with num_trials : 159
# Found 141 / 500, with num_trials : 160
# Found 142 / 500, with num_trials : 161
# Found 143 / 500, with num_trials : 162
# Found 144 / 500, with num_trials : 163
# Found 145 / 500, with num_trials : 164
# Found 146 / 500, with num_trials : 166
# Found 147 / 500, with num_trials : 167
# Found 148 / 500, with num_trials : 168
# Found 149 / 500, with num_trials : 169
# Found 150 / 500, with num_trials : 170
# Found 151 / 500, with num_trials : 172
# Found 152 / 500, with num_trials : 173
# Found 153 / 500, with num_trials : 175
# Found 154 / 500, with num_trials : 177
# Found 155 / 500, with num_trials : 178
# Found 156 / 500, with num_trials : 179
# Found 157 / 500, with num_trials : 180
# Found 158 / 500, with num_trials : 181
# Found 159 / 500, with num_trials : 183
# Found 160 / 500, with num_trials : 184
# Found 161 / 500, with num_trials : 185
# Found 162 / 500, with num_trials : 186
# Found 163 / 500, with num_trials : 187
# Found 164 / 500, with num_trials : 190
# Found 165 / 500, with num_trials : 191
# Found 166 / 500, with num_trials : 192
# Found 167 / 500, with num_trials : 193
# Found 168 / 500, with num_trials : 194
# Found 169 / 500, with num_trials : 195
# Found 170 / 500, with num_trials : 197
# Found 171 / 500, with num_trials : 198
# Found 172 / 500, with num_trials : 199
# Found 173 / 500, with num_trials : 200
# Found 174 / 500, with num_trials : 201
# Found 175 / 500, with num_trials : 202
# Found 176 / 500, with num_trials : 203
# Found 177 / 500, with num_trials : 204
# Found 178 / 500, with num_trials : 205
# Found 179 / 500, with num_trials : 206
# Found 180 / 500, with num_trials : 207
# Found 181 / 500, with num_trials : 208
# Found 182 / 500, with num_trials : 210
# Found 183 / 500, with num_trials : 211
# Found 184 / 500, with num_trials : 212
# Found 185 / 500, with num_trials : 215
# Found 186 / 500, with num_trials : 216
# Found 187 / 500, with num_trials : 217
# Found 188 / 500, with num_trials : 218
# Found 189 / 500, with num_trials : 219
# Found 190 / 500, with num_trials : 220
# Found 191 / 500, with num_trials : 221
# Found 192 / 500, with num_trials : 223
# Found 193 / 500, with num_trials : 224
# Found 194 / 500, with num_trials : 226
# Found 195 / 500, with num_trials : 228
# Found 196 / 500, with num_trials : 230
# Found 197 / 500, with num_trials : 231
# Found 198 / 500, with num_trials : 232
# Found 199 / 500, with num_trials : 233
# Found 200 / 500, with num_trials : 234
# Found 201 / 500, with num_trials : 235
# Found 202 / 500, with num_trials : 236
# Found 203 / 500, with num_trials : 237
# Found 204 / 500, with num_trials : 238
# Found 205 / 500, with num_trials : 239
# Found 206 / 500, with num_trials : 240
# Found 207 / 500, with num_trials : 241
# Found 208 / 500, with num_trials : 242
# Found 209 / 500, with num_trials : 243
# Found 210 / 500, with num_trials : 244
# Found 211 / 500, with num_trials : 245
# Found 212 / 500, with num_trials : 246
# Found 213 / 500, with num_trials : 248
# Found 214 / 500, with num_trials : 254
# Found 215 / 500, with num_trials : 255
# Found 216 / 500, with num_trials : 256
# Found 217 / 500, with num_trials : 257
# Found 218 / 500, with num_trials : 258
# Found 219 / 500, with num_trials : 259
# Found 220 / 500, with num_trials : 260
# Found 221 / 500, with num_trials : 261
# Found 222 / 500, with num_trials : 263
# Found 223 / 500, with num_trials : 265
# Found 224 / 500, with num_trials : 266
# Found 225 / 500, with num_trials : 267
# Found 226 / 500, with num_trials : 268
# Found 227 / 500, with num_trials : 269
# Found 228 / 500, with num_trials : 271
# Found 229 / 500, with num_trials : 272
# Found 230 / 500, with num_trials : 273
# Found 231 / 500, with num_trials : 274
# Found 232 / 500, with num_trials : 275
# Found 233 / 500, with num_trials : 276
# Found 234 / 500, with num_trials : 277
# Found 235 / 500, with num_trials : 278
# Found 236 / 500, with num_trials : 279
# Found 237 / 500, with num_trials : 280
# Found 238 / 500, with num_trials : 281
# Found 239 / 500, with num_trials : 282
# ...
# Found 123 / 500, with num_trials : 621
# Found 124 / 500, with num_trials : 629
# Found 125 / 500, with num_trials : 633
# Found 126 / 500, with num_trials : 634
# Found 127 / 500, with num_trials : 636
# Found 128 / 500, with num_trials : 637
# Found 129 / 500, with num_trials : 646
# Found 130 / 500, with num_trials : 651
# Found 131 / 500, with num_trials : 670
# Found 132 / 500, with num_trials : 678
# Found 133 / 500, with num_trials : 685
# Found 134 / 500, with num_trials : 686
# Found 135 / 500, with num_trials : 687
# Found 136 / 500, with num_trials : 688
# Found 137 / 500, with num_trials : 692
# Found 138 / 500, with num_trials : 698
# Found 139 / 500, with num_trials : 700
# Found 140 / 500, with num_trials : 709
# Found 141 / 500, with num_trials : 715
# Found 142 / 500, with num_trials : 716
# Found 143 / 500, with num_trials : 723
# Found 144 / 500, with num_trials : 731
# Found 145 / 500, with num_trials : 733
# Found 146 / 500, with num_trials : 736
# Found 147 / 500, with num_trials : 737
# Found 148 / 500, with num_trials : 746
# Found 149 / 500, with num_trials : 751
# Found 150 / 500, with num_trials : 753
# Found 151 / 500, with num_trials : 754
# Found 152 / 500, with num_trials : 755
# Found 153 / 500, with num_trials : 765
# Found 154 / 500, with num_trials : 768
# Found 155 / 500, with num_trials : 770
# Found 156 / 500, with num_trials : 776
# Found 157 / 500, with num_trials : 782
# Found 158 / 500, with num_trials : 786
# Found 159 / 500, with num_trials : 792
# Found 160 / 500, with num_trials : 793
# Found 161 / 500, with num_trials : 799
# UPDATE: Found 161 / 500, with num_trials : 800
# Found 162 / 500, with num_trials : 809
# Found 163 / 500, with num_trials : 810
# Found 164 / 500, with num_trials : 815
# Found 165 / 500, with num_trials : 816
# Found 166 / 500, with num_trials : 821
# Found 167 / 500, with num_trials : 830
# Found 168 / 500, with num_trials : 831
# Found 169 / 500, with num_trials : 832
# Found 170 / 500, with num_trials : 839
# Found 171 / 500, with num_trials : 843
# Found 172 / 500, with num_trials : 850
# Found 173 / 500, with num_trials : 852
# Found 174 / 500, with num_trials : 855
# Found 175 / 500, with num_trials : 868
# Found 176 / 500, with num_trials : 871
# Found 177 / 500, with num_trials : 872
# Found 178 / 500, with num_trials : 874
# Found 179 / 500, with num_trials : 888
# Found 180 / 500, with num_trials : 889
# Found 181 / 500, with num_trials : 890
# Found 182 / 500, with num_trials : 895
# Found 183 / 500, with num_trials : 897
# Found 184 / 500, with num_trials : 899
# Found 185 / 500, with num_trials : 900
# Found 186 / 500, with num_trials : 901
# Found 187 / 500, with num_trials : 910
# Found 188 / 500, with num_trials : 911
# Found 189 / 500, with num_trials : 912
# Found 190 / 500, with num_trials : 915
# Found 191 / 500, with num_trials : 916
# Found 192 / 500, with num_trials : 917
# Found 193 / 500, with num_trials : 918
# Found 194 / 500, with num_trials : 924
# Found 195 / 500, with num_trials : 930
# Found 196 / 500, with num_trials : 931
# Found 197 / 500, with num_trials : 932
# Found 198 / 500, with num_trials : 937
# Found 199 / 500, with num_trials : 938
# Found 200 / 500, with num_trials : 940
# Found 201 / 500, with num_trials : 941
# Found 202 / 500, with num_trials : 947
# Found 203 / 500, with num_trials : 951
# Found 204 / 500, with num_trials : 952
# Found 205 / 500, with num_trials : 953
# Found 206 / 500, with num_trials : 956
# Found 207 / 500, with num_trials : 957
# Found 208 / 500, with num_trials : 974
# Found 209 / 500, with num_trials : 977
# Found 210 / 500, with num_trials : 987
# Found 211 / 500, with num_trials : 994
# UPDATE: Found 211 / 500, with num_trials : 1000
# Found 212 / 500, with num_trials : 1003
# Found 213 / 500, with num_trials : 1004
# Found 214 / 500, with num_trials : 1005
# Found 215 / 500, with num_trials : 1010
# Found 216 / 500, with num_trials : 1024
# Found 217 / 500, with num_trials : 1026
# Found 218 / 500, with num_trials : 1036
# Found 219 / 500, with num_trials : 1041
# Found 220 / 500, with num_trials : 1042
# Found 221 / 500, with num_trials : 1043
# Found 222 / 500, with num_trials : 1051
# Found 223 / 500, with num_trials : 1062
# Found 224 / 500, with num_trials : 1065
# Found 225 / 500, with num_trials : 1071
# Found 226 / 500, with num_trials : 1074
# Found 227 / 500, with num_trials : 1079
# Found 228 / 500, with num_trials : 1085
# Found 229 / 500, with num_trials : 1091
# UPDATE: Found 229 / 500, with num_trials : 1100
# Found 230 / 500, with num_trials : 1101
# Found 231 / 500, with num_trials : 1109
# Found 232 / 500, with num_trials : 1115
# Found 233 / 500, with num_trials : 1128
# Found 234 / 500, with num_trials : 1134
# Found 235 / 500, with num_trials : 1135
# Found 236 / 500, with num_trials : 1137
# Found 237 / 500, with num_trials : 1138
# Found 238 / 500, with num_trials : 1148
# Found 239 / 500, with num_trials : 1151
# Found 240 / 500, with num_trials : 1152
# Found 241 / 500, with num_trials : 1153
# Found 242 / 500, with num_trials : 1154
# Found 243 / 500, with num_trials : 1155
# Found 244 / 500, with num_trials : 1168
# Found 245 / 500, with num_trials : 1172
# Found 246 / 500, with num_trials : 1175
# Found 247 / 500, with num_trials : 1182
# Found 248 / 500, with num_trials : 1188
# Found 249 / 500, with num_trials : 1189
# Found 250 / 500, with num_trials : 1190
# Found 251 / 500, with num_trials : 1198
# UPDATE: Found 251 / 500, with num_trials : 1200
# Found 252 / 500, with num_trials : 1202
# Found 253 / 500, with num_trials : 1203
# Found 254 / 500, with num_trials : 1232
# Found 255 / 500, with num_trials : 1233
# Found 256 / 500, with num_trials : 1235
# Found 257 / 500, with num_trials : 1236
# Found 258 / 500, with num_trials : 1262
# Found 259 / 500, with num_trials : 1267
# Found 260 / 500, with num_trials : 1285
# Found 261 / 500, with num_trials : 1287
# Found 262 / 500, with num_trials : 1295
# Found 263 / 500, with num_trials : 1297
# UPDATE: Found 263 / 500, with num_trials : 1300
# Found 264 / 500, with num_trials : 1313
# Found 265 / 500, with num_trials : 1318
# Found 266 / 500, with num_trials : 1338
# Found 267 / 500, with num_trials : 1341
# Found 268 / 500, with num_trials : 1342
# Found 269 / 500, with num_trials : 1343
# Found 270 / 500, with num_trials : 1345
# Found 271 / 500, with num_trials : 1350
# Found 272 / 500, with num_trials : 1354
# Found 273 / 500, with num_trials : 1357
# Found 274 / 500, with num_trials : 1358
# Found 275 / 500, with num_trials : 1359
# Found 276 / 500, with num_trials : 1366
# Found 277 / 500, with num_trials : 1368
# Found 278 / 500, with num_trials : 1369
# Found 279 / 500, with num_trials : 1370
# Found 280 / 500, with num_trials : 1374
# Found 281 / 500, with num_trials : 1377
# Found 282 / 500, with num_trials : 1384
# Found 283 / 500, with num_trials : 1389
# Found 284 / 500, with num_trials : 1390
# Found 285 / 500, with num_trials : 1391
# Found 286 / 500, with num_trials : 1392
# Found 287 / 500, with num_trials : 1396
# UPDATE: Found 287 / 500, with num_trials : 1400
# Found 288 / 500, with num_trials : 1404
# Found 289 / 500, with num_trials : 1411
# Found 290 / 500, with num_trials : 1417
# Found 291 / 500, with num_trials : 1421
# Found 292 / 500, with num_trials : 1427
# Found 293 / 500, with num_trials : 1429
# Found 294 / 500, with num_trials : 1436
# Found 295 / 500, with num_trials : 1442
# Found 296 / 500, with num_trials : 1443
# Found 297 / 500, with num_trials : 1446
# Found 298 / 500, with num_trials : 1449
# Found 299 / 500, with num_trials : 1458
# Found 300 / 500, with num_trials : 1463
# Found 301 / 500, with num_trials : 1468
# Found 302 / 500, with num_trials : 1473
# Found 303 / 500, with num_trials : 1483
# Found 304 / 500, with num_trials : 1485
# Found 305 / 500, with num_trials : 1490
# Found 306 / 500, with num_trials : 1491
# UPDATE: Found 306 / 500, with num_trials : 1500
# Found 307 / 500, with num_trials : 1510
# Found 308 / 500, with num_trials : 1518
# Found 309 / 500, with num_trials : 1519
# Found 310 / 500, with num_trials : 1521
# Found 311 / 500, with num_trials : 1523
# Found 312 / 500, with num_trials : 1524
# Found 313 / 500, with num_trials : 1525
# Found 314 / 500, with num_trials : 1526
# Found 315 / 500, with num_trials : 1527
# Found 316 / 500, with num_trials : 1530
# Found 317 / 500, with num_trials : 1536
# Found 318 / 500, with num_trials : 1538
# Found 319 / 500, with num_trials : 1539
# Found 320 / 500, with num_trials : 1541
# Found 321 / 500, with num_trials : 1549
# Found 322 / 500, with num_trials : 1550
# Found 323 / 500, with num_trials : 1554
# Found 324 / 500, with num_trials : 1555
# Found 325 / 500, with num_trials : 1563
# Found 326 / 500, with num_trials : 1573
# Found 327 / 500, with num_trials : 1576
# Found 328 / 500, with num_trials : 1581
# Found 329 / 500, with num_trials : 1583
# Found 330 / 500, with num_trials : 1596
# UPDATE: Found 330 / 500, with num_trials : 1600
# Found 331 / 500, with num_trials : 1608
# Found 332 / 500, with num_trials : 1617
# Found 333 / 500, with num_trials : 1628
# Found 334 / 500, with num_trials : 1630
# Found 335 / 500, with num_trials : 1637
# Found 336 / 500, with num_trials : 1644
# Found 337 / 500, with num_trials : 1646
# Found 338 / 500, with num_trials : 1649
# Found 339 / 500, with num_trials : 1654
# Found 340 / 500, with num_trials : 1658
# Found 341 / 500, with num_trials : 1660
# Found 342 / 500, with num_trials : 1665
# Found 343 / 500, with num_trials : 1672
# Found 344 / 500, with num_trials : 1675
# Found 345 / 500, with num_trials : 1676
# Found 346 / 500, with num_trials : 1677
# Found 347 / 500, with num_trials : 1679
# Found 348 / 500, with num_trials : 1680
# Found 349 / 500, with num_trials : 1683
# Found 350 / 500, with num_trials : 1685
# Found 351 / 500, with num_trials : 1689
# Found 352 / 500, with num_trials : 1690
# Found 353 / 500, with num_trials : 1692
# Found 354 / 500, with num_trials : 1694
# Found 355 / 500, with num_trials : 1697
# UPDATE: Found 355 / 500, with num_trials : 1700
# Found 356 / 500, with num_trials : 1702
# Found 357 / 500, with num_trials : 1703
# Found 358 / 500, with num_trials : 1708
# Found 359 / 500, with num_trials : 1723
# Found 360 / 500, with num_trials : 1743
# Found 361 / 500, with num_trials : 1746
# Found 362 / 500, with num_trials : 1748
# Found 363 / 500, with num_trials : 1762
# Found 364 / 500, with num_trials : 1775
# Found 365 / 500, with num_trials : 1779
# Found 366 / 500, with num_trials : 1786
# Found 367 / 500, with num_trials : 1787
# Found 368 / 500, with num_trials : 1789
# UPDATE: Found 368 / 500, with num_trials : 1800
# Found 369 / 500, with num_trials : 1801
# Found 370 / 500, with num_trials : 1811
# Found 371 / 500, with num_trials : 1815
# Found 372 / 500, with num_trials : 1817
# Found 373 / 500, with num_trials : 1818
# Found 374 / 500, with num_trials : 1820
# Found 375 / 500, with num_trials : 1830
# Found 376 / 500, with num_trials : 1838
# Found 377 / 500, with num_trials : 1839
# Found 378 / 500, with num_trials : 1868
# Found 379 / 500, with num_trials : 1893
# UPDATE: Found 379 / 500, with num_trials : 1900
# Found 380 / 500, with num_trials : 1919
# Found 381 / 500, with num_trials : 1921
# Found 382 / 500, with num_trials : 1922
# Found 383 / 500, with num_trials : 1937
# Found 384 / 500, with num_trials : 1943
# Found 385 / 500, with num_trials : 1945
# Found 386 / 500, with num_trials : 1950
# Found 387 / 500, with num_trials : 1969
# Found 388 / 500, with num_trials : 1975
# Found 389 / 500, with num_trials : 1989
# Found 390 / 500, with num_trials : 1992
# Found 391 / 500, with num_trials : 1995
# Found 392 / 500, with num_trials : 2000
# Found 393 / 500, with num_trials : 2017
# Found 394 / 500, with num_trials : 2018
# Found 395 / 500, with num_trials : 2022
# Found 396 / 500, with num_trials : 2027
# Found 397 / 500, with num_trials : 2028
# Found 398 / 500, with num_trials : 2034
# Found 399 / 500, with num_trials : 2053
# Found 400 / 500, with num_trials : 2054
# Found 401 / 500, with num_trials : 2069
# Found 402 / 500, with num_trials : 2074
# Found 403 / 500, with num_trials : 2075
# Found 404 / 500, with num_trials : 2081
# Found 405 / 500, with num_trials : 2082
# Found 406 / 500, with num_trials : 2091
# Found 407 / 500, with num_trials : 2096
# Found 408 / 500, with num_trials : 2097
# Found 409 / 500, with num_trials : 2098
# UPDATE: Found 409 / 500, with num_trials : 2100
# Found 410 / 500, with num_trials : 2108
# Found 411 / 500, with num_trials : 2109
# Found 412 / 500, with num_trials : 2110
# Found 413 / 500, with num_trials : 2111
# Found 414 / 500, with num_trials : 2114
# Found 415 / 500, with num_trials : 2119
# Found 416 / 500, with num_trials : 2127
# Found 417 / 500, with num_trials : 2128
# Found 418 / 500, with num_trials : 2130
# Found 419 / 500, with num_trials : 2136
# Found 420 / 500, with num_trials : 2142
# Found 421 / 500, with num_trials : 2160
# Found 422 / 500, with num_trials : 2168
# Found 423 / 500, with num_trials : 2185
# Found 424 / 500, with num_trials : 2188
# Found 425 / 500, with num_trials : 2189
# Found 426 / 500, with num_trials : 2197
# UPDATE: Found 426 / 500, with num_trials : 2200
# Found 427 / 500, with num_trials : 2202
# Found 428 / 500, with num_trials : 2205
# Found 429 / 500, with num_trials : 2206
# Found 430 / 500, with num_trials : 2208
# Found 431 / 500, with num_trials : 2212
# Found 432 / 500, with num_trials : 2213
# Found 433 / 500, with num_trials : 2223
# Found 434 / 500, with num_trials : 2224
# Found 435 / 500, with num_trials : 2253
# Found 436 / 500, with num_trials : 2269
# Found 437 / 500, with num_trials : 2271
# Found 438 / 500, with num_trials : 2274
# Found 439 / 500, with num_trials : 2282
# UPDATE: Found 439 / 500, with num_trials : 2300
# Found 440 / 500, with num_trials : 2307
# Found 441 / 500, with num_trials : 2330
# Found 442 / 500, with num_trials : 2332
# Found 443 / 500, with num_trials : 2334
# Found 444 / 500, with num_trials : 2342
# Found 445 / 500, with num_trials : 2343
# Found 446 / 500, with num_trials : 2348
# Found 447 / 500, with num_trials : 2350
# Found 448 / 500, with num_trials : 2351
# Found 449 / 500, with num_trials : 2352
# Found 450 / 500, with num_trials : 2362
# Found 451 / 500, with num_trials : 2369
# Found 452 / 500, with num_trials : 2374
# Found 453 / 500, with num_trials : 2382
# Found 454 / 500, with num_trials : 2383
# Found 455 / 500, with num_trials : 2385
# Found 456 / 500, with num_trials : 2387
# UPDATE: Found 456 / 500, with num_trials : 2400
# Found 457 / 500, with num_trials : 2415
# Found 458 / 500, with num_trials : 2418
# Found 459 / 500, with num_trials : 2419
# Found 460 / 500, with num_trials : 2421
# Found 461 / 500, with num_trials : 2422
# Found 462 / 500, with num_trials : 2423
# Found 463 / 500, with num_trials : 2424
# Found 464 / 500, with num_trials : 2428
# Found 465 / 500, with num_trials : 2437
# Found 466 / 500, with num_trials : 2438
# Found 467 / 500, with num_trials : 2441
# Found 468 / 500, with num_trials : 2445
# Found 469 / 500, with num_trials : 2446
# Found 470 / 500, with num_trials : 2462
# Found 471 / 500, with num_trials : 2464
# Found 472 / 500, with num_trials : 2471
# Found 473 / 500, with num_trials : 2484
# Found 474 / 500, with num_trials : 2485
# Found 475 / 500, with num_trials : 2488
# Found 476 / 500, with num_trials : 2490
# Found 477 / 500, with num_trials : 2491
# Found 478 / 500, with num_trials : 2492
# UPDATE: Found 478 / 500, with num_trials : 2500
# Found 479 / 500, with num_trials : 2532
# Found 480 / 500, with num_trials : 2533
# Found 481 / 500, with num_trials : 2535
# Found 482 / 500, with num_trials : 2547
# Found 483 / 500, with num_trials : 2553
# Found 484 / 500, with num_trials : 2558
# Found 485 / 500, with num_trials : 2566
# Found 486 / 500, with num_trials : 2572
# Found 487 / 500, with num_trials : 2578
# Found 488 / 500, with num_trials : 2582
# Found 489 / 500, with num_trials : 2586
# Found 490 / 500, with num_trials : 2598
# UPDATE: Found 490 / 500, with num_trials : 2600
# Found 491 / 500, with num_trials : 2618
# Found 492 / 500, with num_trials : 2628
# Found 493 / 500, with num_trials : 2630
# Found 494 / 500, with num_trials : 2637
# Found 495 / 500, with num_trials : 2639
# Found 496 / 500, with num_trials : 2641
# Found 497 / 500, with num_trials : 2642
# Found 498 / 500, with num_trials : 2644
# Found 499 / 500, with num_trials : 2646
# Found 500 / 500, with num_trials : 2648
# Finished p=0.0199526231496888 with num_trials=2649
# ------------------------------------------------------------------

# %%
results
# Out:
# array([2649, 3653, 4215, 3583, 2379, 1354,  883,  609,  536,  502])

# %%
results = np.flip(simulate_ldpc(field, h72, l72, max_iter, 100, physical_error))

# %%
results = np.flip(simulate(field5, h72_5, l72_5, max_iter, 20, physical_error))

# %%
x_order = ['Idle', 0, 3, 1, 2]
z_order = [0, 3, 1, 2, 'Idle']
max_iter = 100

num_cycles = 5
circ = bb25.construct_sm_circuit(x_order, z_order)

# %%
circ_physical_error = np.flip(np.logspace(-2.3, -2, 10))
circ_physical_error
# Out:
# array([0.01      , 0.00926119, 0.00857696, 0.00794328, 0.00735642,
#        0.00681292, 0.00630957, 0.00584341, 0.0054117 , 0.00501187])

# %%
results = circ_simulate(Field(2), bb25, circ, num_cycles, max_iter, 5, circ_physical_error)
# Out:
# Constructing decoding matrix for p=0.01...
# Constructed decoding matrix for p=0.01
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:142: RuntimeWarning: invalid value encountered in divide
#   sub_posteriors = sub_posteriors / posterior
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: divide by zero encountered in divide
#   posteriors /= (
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:165: RuntimeWarning: invalid value encountered in divide
#   posteriors /= (
# C:\Users\elean\Documents\Quantum-Computing-PhD\ITP\IP-BBQ\qudit-bivariate-bicycle\bbq\decoder.py:120: RuntimeWarning: invalid value encountered in divide
#   sub_convolutions = sub_convolutions / convolution
# Found 1 / 5, with num_trials : 0
# Found 2 / 5, with num_trials : 1
# Found 3 / 5, with num_trials : 2
# Found 4 / 5, with num_trials : 5
# Found 5 / 5, with num_trials : 7
# Finished p=0.01 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.009261187281287938...
# Constructed decoding matrix for p=0.009261187281287938
# Found 1 / 5, with num_trials : 0
# Found 2 / 5, with num_trials : 3
# Found 3 / 5, with num_trials : 4
# Found 4 / 5, with num_trials : 5
# Found 5 / 5, with num_trials : 7
# Finished p=0.009261187281287938 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.008576958985908946...
# Constructed decoding matrix for p=0.008576958985908946
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 1
# Found 2 / 5, with num_trials : 3
# Found 3 / 5, with num_trials : 5
# Found 4 / 5, with num_trials : 6
# Found 5 / 5, with num_trials : 7
# Finished p=0.008576958985908946 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.007943282347242814...
# Constructed decoding matrix for p=0.007943282347242814
# Found 1 / 5, with num_trials : 0
# Found 2 / 5, with num_trials : 1
# Found 3 / 5, with num_trials : 3
# Found 4 / 5, with num_trials : 4
# Found 5 / 5, with num_trials : 5
# Finished p=0.007943282347242814 with num_trials=6
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.007356422544596414...
# Constructed decoding matrix for p=0.007356422544596414
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 4
# Found 2 / 5, with num_trials : 5
# Found 3 / 5, with num_trials : 7
# Found 4 / 5, with num_trials : 8
# Found 5 / 5, with num_trials : 9
# Finished p=0.007356422544596414 with num_trials=10
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.006812920690579615...
# Constructed decoding matrix for p=0.006812920690579615
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 5
# Found 2 / 5, with num_trials : 7
# Found 3 / 5, with num_trials : 9
# Found 4 / 5, with num_trials : 11
# Found 5 / 5, with num_trials : 12
# Finished p=0.006812920690579615 with num_trials=13
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.006309573444801936...
# Constructed decoding matrix for p=0.006309573444801936
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 1
# Found 2 / 5, with num_trials : 2
# Found 3 / 5, with num_trials : 3
# Found 4 / 5, with num_trials : 4
# Found 5 / 5, with num_trials : 7
# Finished p=0.006309573444801936 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.005843414133735175...
# Constructed decoding matrix for p=0.005843414133735175
# Found 1 / 5, with num_trials : 0
# Found 2 / 5, with num_trials : 5
# Found 3 / 5, with num_trials : 8
# Found 4 / 5, with num_trials : 12
# Found 5 / 5, with num_trials : 13
# Finished p=0.005843414133735175 with num_trials=14
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.0054116952654646375...
# Constructed decoding matrix for p=0.0054116952654646375
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 3
# Found 2 / 5, with num_trials : 4
# Found 3 / 5, with num_trials : 5
# Found 4 / 5, with num_trials : 6
# Found 5 / 5, with num_trials : 7
# Finished p=0.0054116952654646375 with num_trials=8
# ------------------------------------------------------------------
# Constructing decoding matrix for p=0.005011872336272725...
# Constructed decoding matrix for p=0.005011872336272725
# UPDATE: Found 0 / 5, with num_trials : 0
# Found 1 / 5, with num_trials : 1
# Found 2 / 5, with num_trials : 2
# Found 3 / 5, with num_trials : 3
# Found 4 / 5, with num_trials : 5
# Found 5 / 5, with num_trials : 7
# Finished p=0.005011872336272725 with num_trials=8
# ------------------------------------------------------------------
